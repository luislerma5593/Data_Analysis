# %% [markdown]
# # 3. Procesamiento de datos con Python

# %%
import pandas as pd

# %%
h = pd.read_csv("C:/Users/LLerma/Documents/GitHub/Data_Analysis/Proyecto/3. Procesamiento de datos Python/Files/m12.csv")

# %%
h.head()
# Out:
#   FinishedTime  ID  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0   01/01/2020   1           1            2     100.1     52.9      47.2
# 1   01/01/2020   1           2            2      70.0     48.6      21.4
# 2   01/01/2020   1           3            2      83.6     46.2      37.4
# 3   01/01/2020   1           4            2      91.0     50.7      40.3
# 4   01/01/2020   1           5            2      88.6     51.4      37.2
#
#    Turnaround  Utilization  IsPartial  ...  AutoLowerProfile  CaveInProfile  \
# 0           0    52.847153          0  ...                 1              1
# 1           0    69.428571          0  ...                 1              1
# 2           0    55.263158          0  ...                 1              1
# 3           0    55.714286          0  ...                 1              1
# 4           0    58.013544          0  ...                 1              1
#
# ...

# %%
h1 = h[h["ID"]==1]
h2 = h[h["ID"]==2]

# %%
h1
# Out:
#      FinishedTime  ID  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0      01/01/2020   1           1            2     100.1     52.9      47.2
# 1      01/01/2020   1           2            2      70.0     48.6      21.4
# 2      01/01/2020   1           3            2      83.6     46.2      37.4
# 3      01/01/2020   1           4            2      91.0     50.7      40.3
# 4      01/01/2020   1           5            2      88.6     51.4      37.2
# ...           ...  ..         ...          ...       ...      ...       ...
# 4547   30/12/2020   1        4548            2     189.5     29.2     160.3
# 4548   30/12/2020   1        4549            2     204.4      9.2     195.2
# 4549   30/12/2020   1        4550            2     207.5     60.6     146.9
# 4550   31/12/2020   1        4551            2     211.8     63.0     148.8
# 4551   31/12/2020   1        4552            2     126.9     62.9      64.0
#
# ...

# %%
h1 = h1.drop(columns=['ID'])
h1.head(1)
# Out:
#   FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0   01/01/2020           1            2     100.1     52.9      47.2
#
#    Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 0           0    52.847153          0        4  ...                 1
#
#    CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# 0              1               1                1                 1
#
#    MasterGainProfile  NCCProfile  RampsProfile  ShaperProfile     I2TMwh
# 0                  1           1             1              1  55.681016
#
# [1 rows x 219 columns]

# %%
h2 = h2.drop(columns=['ID'])
h2 = h2.reset_index(drop = True)
h2
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0      01/01/2020           1            2     111.2     38.7      72.5
# 1      01/01/2020           2            2     111.7     38.7      73.0
# 2      01/01/2020           3            2     142.3     39.9     102.4
# 3      01/01/2020           4            2     142.6     39.9     102.7
# 4      01/01/2020           5            2      62.1     39.3      22.8
# ...           ...         ...          ...       ...      ...       ...
# 7155   31/12/2020        7156            2      59.6     40.5      19.1
# 7156   31/12/2020        7157            2      58.0     41.5      16.5
# 7157   31/12/2020        7158            2      63.7     40.4      23.3
# 7158   31/12/2020        7159            2      71.6     39.4      32.2
# 7159   31/12/2020        7160            2     454.0     44.7     454.0
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# ...

# %%
list(h1)
# Out:
# ['FinishedTime',
#  'HeatNumber',
#  'ControlMode',
#  'TapToTap',
#  'PowerOn',
#  'PowerOff',
#  'Turnaround',
#  'Utilization',
#  'IsPartial',
#  'Charges',
#  'ShadowModePwrOnPercent',
#  'ControlSmartARCPercent',
#  'ControlPowerProgramPercent',
#  'ControlManualPercent',
#  'HeatAvgMW',
#  'EnergyPerChargeTon',
#  'EnergyPerHeat',
#  'OffLoadPriV',
#  'OnLoadPriV',
#  'AvgCurrent1',
#  'AvgCurrent2',
#  'AvgCurrent3',
#  'AvgVoltage1',
#  'AvgVoltage2',
#  'AvgVoltage3',
#  'TotalAvgCurrent',
#  'TotalAvgVoltage',
#  'PowerFactor1',
#  'PowerFactor2',
#  'PowerFactor3',
#  'RealPower1',
#  'RealPower2',
#  'RealPower3',
#  'ReactivePower1',
#  'ReactivePower2',
#  'ReactivePower3',
#  'ApparentPower1',
#  'ApparentPower2',
#  'ApparentPower3',
#  'NonConductorCount1',
#  'NonConductorCount2',
#  'NonConductorCount3',
#  'NonConductorTime1',
#  'NonConductorTime2',
#  'NonConductorTime3',
#  'SinglePhasingCount1',
#  'SinglePhasingCount2',
#  'SinglePhasingCount3',
# ...

# %%
list(h2)
# Out:
# ['FinishedTime',
#  'HeatNumber',
#  'ControlMode',
#  'TapToTap',
#  'PowerOn',
#  'PowerOff',
#  'Turnaround',
#  'Utilization',
#  'IsPartial',
#  'Charges',
#  'ShadowModePwrOnPercent',
#  'ControlSmartARCPercent',
#  'ControlPowerProgramPercent',
#  'ControlManualPercent',
#  'HeatAvgMW',
#  'EnergyPerChargeTon',
#  'EnergyPerHeat',
#  'OffLoadPriV',
#  'OnLoadPriV',
#  'AvgCurrent1',
#  'AvgCurrent2',
#  'AvgCurrent3',
#  'AvgVoltage1',
#  'AvgVoltage2',
#  'AvgVoltage3',
#  'TotalAvgCurrent',
#  'TotalAvgVoltage',
#  'PowerFactor1',
#  'PowerFactor2',
#  'PowerFactor3',
#  'RealPower1',
#  'RealPower2',
#  'RealPower3',
#  'ReactivePower1',
#  'ReactivePower2',
#  'ReactivePower3',
#  'ApparentPower1',
#  'ApparentPower2',
#  'ApparentPower3',
#  'NonConductorCount1',
#  'NonConductorCount2',
#  'NonConductorCount3',
#  'NonConductorTime1',
#  'NonConductorTime2',
#  'NonConductorTime3',
#  'SinglePhasingCount1',
#  'SinglePhasingCount2',
#  'SinglePhasingCount3',
# ...

# %%
h1.dtypes
# Out:
# FinishedTime          object
# HeatNumber             int64
# ControlMode            int64
# TapToTap             float64
# PowerOn              float64
#                       ...
# MasterGainProfile      int64
# NCCProfile             int64
# RampsProfile           int64
# ShaperProfile          int64
# I2TMwh               float64
# Length: 219, dtype: object

# %%
h2.dtypes
# Out:
# FinishedTime          object
# HeatNumber             int64
# ControlMode            int64
# TapToTap             float64
# PowerOn              float64
#                       ...
# MasterGainProfile      int64
# NCCProfile             int64
# RampsProfile           int64
# ShaperProfile          int64
# I2TMwh               float64
# Length: 219, dtype: object

# %%
h1["FinishedTime"] = pd.to_datetime(h1['FinishedTime'], format = "%d/%m/%Y")
h1
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0      2020-01-01           1            2     100.1     52.9      47.2
# 1      2020-01-01           2            2      70.0     48.6      21.4
# 2      2020-01-01           3            2      83.6     46.2      37.4
# 3      2020-01-01           4            2      91.0     50.7      40.3
# 4      2020-01-01           5            2      88.6     51.4      37.2
# ...           ...         ...          ...       ...      ...       ...
# 4547   2020-12-30        4548            2     189.5     29.2     160.3
# 4548   2020-12-30        4549            2     204.4      9.2     195.2
# 4549   2020-12-30        4550            2     207.5     60.6     146.9
# 4550   2020-12-31        4551            2     211.8     63.0     148.8
# 4551   2020-12-31        4552            2     126.9     62.9      64.0
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# ...

# %%
h2["FinishedTime"] = pd.to_datetime(h2['FinishedTime'], format = "%d/%m/%Y")

# %%
h1.dtypes
# Out:
# FinishedTime         datetime64[ns]
# HeatNumber                    int64
# ControlMode                   int64
# TapToTap                    float64
# PowerOn                     float64
#                           ...
# MasterGainProfile             int64
# NCCProfile                    int64
# RampsProfile                  int64
# ShaperProfile                 int64
# I2TMwh                      float64
# Length: 219, dtype: object

# %%
h2.dtypes
# Out:
# FinishedTime         datetime64[ns]
# HeatNumber                    int64
# ControlMode                   int64
# TapToTap                    float64
# PowerOn                     float64
#                           ...
# MasterGainProfile             int64
# NCCProfile                    int64
# RampsProfile                  int64
# ShaperProfile                 int64
# I2TMwh                      float64
# Length: 219, dtype: object

# %%
h1.head()
# Out:
#   FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0   2020-01-01           1            2     100.1     52.9      47.2
# 1   2020-01-01           2            2      70.0     48.6      21.4
# 2   2020-01-01           3            2      83.6     46.2      37.4
# 3   2020-01-01           4            2      91.0     50.7      40.3
# 4   2020-01-01           5            2      88.6     51.4      37.2
#
#    Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 0           0    52.847153          0        4  ...                 1
# 1           0    69.428571          0        4  ...                 1
# 2           0    55.263158          0        4  ...                 1
# 3           0    55.714286          0        4  ...                 1
# 4           0    58.013544          0        4  ...                 1
#
#    CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %%
h2.head()
# Out:
#   FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0   2020-01-01           1            2     111.2     38.7      72.5
# 1   2020-01-01           2            2     111.7     38.7      73.0
# 2   2020-01-01           3            2     142.3     39.9     102.4
# 3   2020-01-01           4            2     142.6     39.9     102.7
# 4   2020-01-01           5            2      62.1     39.3      22.8
#
#    Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 0           0    34.802158          0        3  ...                 1
# 1           0    34.646374          0        3  ...                 1
# 2           0    28.039353          0        3  ...                 1
# 3           0    27.980365          0        3  ...                 1
# 4           0    63.285024          0        3  ...                 1
#
#    CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %%
h2[h2["FinishedTime"].dt.month == 1]
# Out:
#     FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 0     2020-01-01           1            2     111.2     38.7      72.5
# 1     2020-01-01           2            2     111.7     38.7      73.0
# 2     2020-01-01           3            2     142.3     39.9     102.4
# 3     2020-01-01           4            2     142.6     39.9     102.7
# 4     2020-01-01           5            2      62.1     39.3      22.8
# ..           ...         ...          ...       ...      ...       ...
# 990   2020-01-31         991            2      55.1     38.8      16.3
# 991   2020-01-31         992            2      71.4     38.0      33.4
# 992   2020-01-31         993            2      72.1     38.0      34.1
# 993   2020-01-31         994            2      56.4     37.9      18.5
# 994   2020-01-31         995            2      56.8     37.9      18.9
#
#      Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Estadísticas

# %% [markdown]
# ### Horno 1 - Coladas totales

# %%
len(h1)
# Out:
# 4552

# %% [markdown]
# ### Horno 2 - Coladas totales

# %%
len(h2)
# Out:
# 7160

# %% [markdown]
# ### Horno 1 - Energía total consumida (MWh)

# %%
(h1["EnergyPerHeat"].sum(axis = 0))
# Out:
# 231293.15000000002

# %% [markdown]
# ### Horno 2- Energía total consumida (MWh)

# %%
(h2["EnergyPerHeat"].sum(axis = 0))
# Out:
# 384466.08

# %% [markdown]
# ### Horno 1 - Toneladas totales fundidas

# %%
(h1["ChargesTotalWeight"].sum(axis = 0))
# Out:
# 644852.6

# %% [markdown]
# ### Horno 2 - Toneladas totales fundidas

# %%
(h2["ChargesTotalWeight"].sum(axis = 0))
# Out:
# 1008036.4

# %% [markdown]
# ### Horno 1 - Energía total / Peso total

# %%
231293.15000000002*1000/644852.6
# Out:
# 358.6759982048611

# %% [markdown]
# ### Horno 2 - Energía total / Peso total

# %%
384466.08*1000/1008036.4
# Out:
# 381.4009890912669

# %% [markdown]
# ### Horno 1 - Rendimiento promedio (kWh/ton)

# %%
(h1["EnergyPerChargeTon"].mean(axis = 0))
# Out:
# 310.9880492091394

# %% [markdown]
# ### Horno 2 - Rendimiento promedio (kWh/ton)

# %%
(h2["EnergyPerChargeTon"].mean(axis = 0))
# Out:
# 309.4747346368718

# %% [markdown]
# ### Horno 1 - TapToTap Promedio

# %%
(h1["TapToTap"].mean(axis = 0))
# Out:
# 113.75314147627378

# %% [markdown]
# ### Horno 2 - TapToTap Promedio

# %%
(h2["TapToTap"].mean(axis = 0))
# Out:
# 79.88026536312866

# %% [markdown]
# ---

# %% [markdown]
# # Máximos y mínimos

# %% [markdown]
# ### Horno 1 - TapToTap Max

# %%
h1.sort_values("TapToTap", ascending = False).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 3049   2020-09-10        3050            2    3276.5     76.5    3200.1
# 1701   2020-05-19        1702            2    3272.4     72.4    3200.1
# 1771   2020-05-27        1772            2    3270.3     70.3    3200.1
# 1912   2020-06-09        1913            2    3270.1     70.1    3200.0
# 1911   2020-06-09        1912            2    3270.1     70.1    3200.1
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 3049           0     2.334808          0        4  ...                 1
# 1701           0     2.212443          0        4  ...                 1
# 1771           0     2.149650          0        4  ...                 1
# 1912           0     2.143665          0        4  ...                 1
# 1911           0     2.143665          0        4  ...                 1
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %% [markdown]
# ### Horno 1 - TapToTap Min

# %%
h1.sort_values("TapToTap", ascending = True).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 1510   2020-04-22        1511            3       0.6      0.0       0.6
# 2333   2020-07-15        2334            2       1.4      1.1       0.3
# 2097   2020-06-24        2098            2       6.0      0.7       5.3
# 2680   2020-08-12        2681            2       7.6      5.0       2.6
# 3195   2020-09-20        3196            2       8.4      1.1       7.3
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 1510           0     0.000000          0        2  ...                 1
# 2333           0    78.571429          0        1  ...                 1
# 2097           0    11.666667          0        1  ...                 1
# 2680           0    65.789474          0        1  ...                 1
# 3195           7    13.095238          0        1  ...                 1
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %% [markdown]
# ### Horno 2 - TapToTap Max

# %%
h2.sort_values("TapToTap", ascending = False).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 2738   2020-05-02        2739            2    3276.7     62.9    3276.7
# 2737   2020-04-27        2738            3    3276.7      0.0    3276.7
# 2626   2020-04-14        2627            2    3003.6     59.5    2944.1
# 7066   2020-12-26        7067            2    2523.2     50.1    2473.1
# 6553   2020-11-27        6554            2    2491.4     49.7    2441.7
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 2738           0     1.919614          0        3  ...                 2
# 2737        2420     0.000000          0        1  ...                 2
# 2626           0     1.980956          0        4  ...                 1
# 7066           0     1.985574          0        3  ...                 2
# 6553           0     1.994862          0        3  ...                 2
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %% [markdown]
# ### Horno 2 - TapToTap Min

# %%
h2.sort_values("TapToTap", ascending = True).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 3378   2020-06-07        3379            2       3.9      0.4       3.5
# 2206   2020-03-19        2207            3       4.9      0.0       4.9
# 2207   2020-03-19        2208            3       4.9      0.0       4.9
# 2208   2020-03-19        2209            3       4.9      0.0       4.9
# 4220   2020-07-24        4221            2       5.0      0.4       4.6
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 3378           2     10.25641          0        4  ...                 2
# 2206           0      0.00000          0        1  ...                 1
# 2207           0      0.00000          0        1  ...                 1
# 2208           0      0.00000          0        1  ...                 1
# 4220           4      8.00000          0        4  ...                 2
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %% [markdown]
# ### Horno 1 - Energía Max

# %%
h1.sort_values("EnergyPerHeat", ascending = False)[["EnergyPerHeat"]].head()
# Out:
#       EnergyPerHeat
# 2664          81.97
# 74            78.04
# 2322          77.04
# 4245          76.47
# 3556          75.69

# %% [markdown]
# ### Horno 2 - Energía Max

# %%
h2.sort_values("EnergyPerHeat", ascending = False)[["EnergyPerHeat"]].head(10)
# Out:
#      EnergyPerHeat
# 484         192.56
# 483         192.56
# 482         192.56
# 481         192.53
# 479         129.14
# 480         129.14
# 90          124.81
# 91          124.81
# 683         114.84
# 682         114.66

# %% [markdown]
# # Agrupamientos

# %% [markdown]
# ### Horno 1 - Agrupamiento por días (promedio)

# %%
h1.groupby("FinishedTime").agg("mean")
# Out:
#               HeatNumber  ControlMode    TapToTap    PowerOn    PowerOff  \
# FinishedTime
# 2020-01-01           7.0          2.0   90.123077  46.746154   43.376923
# 2020-01-02          18.0          2.0  177.400000  47.666667  129.733333
# 2020-01-03          29.0          2.0  107.876923  47.484615   60.392308
# 2020-01-04          42.5          2.0  105.978571  46.385714   59.600000
# 2020-01-05          53.0          2.0  181.642857  49.300000  132.342857
# ...                  ...          ...         ...        ...         ...
# 2020-12-27        4509.5          2.0   96.650000  53.021429   43.628571
# 2020-12-28        4523.5          2.0  107.171429  53.200000   53.971429
# 2020-12-29        4534.5          2.0  175.800000  52.875000  122.925000
# 2020-12-30        4544.5          2.0  122.358333  48.233333   74.125000
# 2020-12-31        4551.5          2.0  169.350000  62.950000  106.400000
#
#               Turnaround  Utilization  IsPartial   Charges  \
# FinishedTime
# ...

# %% [markdown]
# ### Horno 2 - Agrupamiento por días (promedio)

# %%
h2.groupby("FinishedTime").agg("mean")
# Out:
#               HeatNumber  ControlMode    TapToTap    PowerOn   PowerOff  \
# FinishedTime
# 2020-01-01          13.5          2.0   81.357692  38.823077  42.534615
# 2020-01-02          38.5          2.0  124.120833  38.483333  85.637500
# 2020-01-03          67.5          2.0   82.179412  41.438235  40.758824
# 2020-01-04         103.5          2.0   75.602632  40.426316  35.176316
# 2020-01-05         137.5          2.0   89.326667  40.370000  48.956667
# ...                  ...          ...         ...        ...        ...
# 2020-12-27        7085.0          2.0   72.800000  37.442105  35.357895
# 2020-12-28        7106.0          2.0   62.886957  38.286957  24.600000
# 2020-12-29        7128.0          2.0   68.138095  37.757143  30.380952
# 2020-12-30        7145.0          2.0  117.461538  40.192308  77.269231
# 2020-12-31        7156.0          2.0  128.555556  40.655556  92.866667
#
#               Turnaround  Utilization  IsPartial   Charges  \
# FinishedTime
# ...

# %% [markdown]
# ### Horno 1 - Agrupamiento por meses (promedio)

# %%
h1.groupby(h1["FinishedTime"].dt.month).mean()
# Out:
#               HeatNumber  ControlMode    TapToTap    PowerOn   PowerOff  \
# FinishedTime
# 1                  187.5     2.002674  121.343048  49.081283  72.284759
# 2                  596.0     2.000000   94.338600  47.342212  47.017833
# 3                 1033.5     2.002315  106.805787  47.608796  59.206019
# 4                 1382.0     2.015094  105.278868  47.740000  57.566415
# 5                 1674.5     2.000000  131.930000  49.781250  82.382500
# 6                 2009.5     2.000000  137.054571  50.112857  86.964571
# 7                 2357.5     2.002890  129.389017  50.082659  79.325434
# 8                 2740.0     2.002387  107.133890  51.212172  55.933652
# 9                 3150.0     2.002494  113.879800  51.097506  62.799751
# 10                3569.5     2.000000  102.502055  50.254338  52.271233
# 11                3986.0     2.002532  107.887342  51.392405  56.582278
# 12                4368.0     2.000000  118.074255  51.979133  66.102710
#
# ...

# %% [markdown]
# ### Horno 2 - Agrupamiento por meses (promedio)

# %%
h2.groupby(h2["FinishedTime"].dt.month).mean()
# Out:
#               HeatNumber  ControlMode   TapToTap    PowerOn   PowerOff  \
# FinishedTime
# 1                  498.0     2.001005  88.458291  39.146935  49.366432
# 2                 1438.0     1.985311  80.055141  43.114463  37.294350
# 3                 2150.5     2.011111  79.670926  43.729630  36.392778
# 4                 2579.5     2.003145  89.035220  45.070126  44.147170
# 5                 2991.0     2.000000  86.856040  44.121188  43.308713
# 6                 3513.0     2.000000  78.470872  42.165677  36.657328
# 7                 4069.5     2.000000  74.224739  39.965505  34.639547
# 8                 4645.5     2.000000  72.459689  37.454498  35.360208
# 9                 5205.5     1.998155  79.308672  38.307380  41.303321
# 10                5761.0     2.000000  74.707030  37.740598  37.377680
# 11                6329.0     2.000000  72.865785  36.953968  36.173545
# 12                6886.5     2.000000  80.819526  37.206204  43.945073
#
# ...

# %%
# h1["FinishedTime"].dt.month

# %% [markdown]
# ---

# %% [markdown]
# # Filtrado $\mu \pm 3\sigma$

# %%
h1.shape
# Out:
# (4552, 219)

# %%
h2.shape
# Out:
# (7160, 219)

# %% [markdown]
# ### Energía

# %%
h1_energy_mean = h1["EnergyPerHeat"].mean()
h2_energy_mean = h2["EnergyPerHeat"].mean()

h1_energy_std = h1["EnergyPerHeat"].std()
h2_energy_std = h2["EnergyPerHeat"].std()

# %%
h1_energy_filter = (h1["EnergyPerHeat"] > (h1_energy_mean - 3 * h1_energy_std)) & (h1["EnergyPerHeat"] < (h1_energy_mean + 3 * h1_energy_std))
h2_energy_filter = (h2["EnergyPerHeat"] > (h2_energy_mean - 3 * h2_energy_std)) & (h2["EnergyPerHeat"] < (h2_energy_mean + 3 * h2_energy_std))

# %% [markdown]
# ---

# %% [markdown]
# ### Power On

# %%
h1_POn_mean = h1["PowerOn"].mean()
h2_POn_mean = h2["PowerOn"].mean()

h1_POn_std = h1["PowerOn"].std()

# %%
h1_POn_filter = (h1["PowerOn"] > (h1_POn_mean - 3 * h1_POn_std)) & (h1["PowerOn"] < (h1_POn_mean + 3 * h1_POn_std))
h2_POn_filter = (h2["PowerOn"] > (h2_POn_mean - 3 * h2_POn_std)) & (h2["PowerOn"] < (h2_POn_mean + 3 * h2_POn_std))

# %% [markdown]
# ---

# %% [markdown]
# ### Tap to Tap

# %%
h1_TT_mean = h1["TapToTap"].mean()
h2_TT_mean = h2["TapToTap"].mean()

h1_TT_std = h1["TapToTap"].std()
h2_TT_std = h2["TapToTap"].std()

# %%
h1_TT_filter = (h1["TapToTap"] > (h1_TT_mean - 50)) & (h1["TapToTap"] < (h1_TT_mean + 50))
h2_TT_filter = (h2["TapToTap"] > (h2_TT_mean - 50)) & (h2["TapToTap"] < (h2_TT_mean + 50))

# %% [markdown]
# ---

# %% [markdown]
# ### kWh / ton

# %%
h1_kWh_mean = h1["EnergyPerChargeTon"].mean()
h2_kWh_mean = h2["EnergyPerChargeTon"].mean()

h1_kWh_std = h1["EnergyPerChargeTon"].std()
h2_kWh_std = h2["EnergyPerChargeTon"].std()

# %%
h1_kWh_filter = (h1["EnergyPerChargeTon"] > (h1_kWh_mean - 100)) & (h1["EnergyPerChargeTon"] < (h1_kWh_mean + 100))
h2_kWh_filter = (h2["EnergyPerChargeTon"] > (h2_kWh_mean - 100)) & (h2["EnergyPerChargeTon"] < (h2_kWh_mean + 100))

# %% [markdown]
# ---

# %% [markdown]
# ### Aplicación de filtros

# %%
len(h1)
# Out:
# 4552

# %%
h1_fil = h1[h1_energy_filter & h1_POn_filter & h1_kWh_filter & h1_TT_filter]
len(h1_fil)
# Out:
# 3718

# %%
len(h2)
# Out:
# 7160

# %%
h2_fil = h2[h2_energy_filter & h2_POn_filter & h2_kWh_filter & h2_TT_filter]
len(h2_fil)
# Out:
# 5881

# %% [markdown]
# ---

# %% [markdown]
# # Estadísticas con los DF filtrados

# %% [markdown]
# ## Horno 1

# %%
h1.sort_values("EnergyPerHeat", ascending = False)[["EnergyPerHeat"]].head()
# Out:
#       EnergyPerHeat
# 2664          81.97
# 74            78.04
# 2322          77.04
# 4245          76.47
# 3556          75.69

# %%
h1_fil.sort_values("EnergyPerHeat", ascending = False)[["EnergyPerHeat"]].head()
# Out:
#       EnergyPerHeat
# 4551          63.96
# 3050          62.86
# 418           62.66
# 23            62.46
# 3863          62.20

# %% [markdown]
# ## Horno 2

# %%
h2.sort_values("EnergyPerHeat", ascending = False)[["EnergyPerHeat"]].head()
# Out:
#      EnergyPerHeat
# 484         192.56
# 483         192.56
# 482         192.56
# 481         192.53
# 479         129.14

# %%
h2_fil.sort_values("EnergyPerHeat", ascending = False)[["EnergyPerHeat"]].head()
# Out:
#       EnergyPerHeat
# 711           67.04
# 86            65.36
# 4992          65.29
# 6759          64.46
# 5094          64.11

# %% [markdown]
# ## Horno 1 - Agrupación sin filtro

# %%
h1.groupby(h1["FinishedTime"].dt.month).mean()
# Out:
#               HeatNumber  ControlMode    TapToTap    PowerOn   PowerOff  \
# FinishedTime
# 1                  187.5     2.002674  121.343048  49.081283  72.284759
# 2                  596.0     2.000000   94.338600  47.342212  47.017833
# 3                 1033.5     2.002315  106.805787  47.608796  59.206019
# 4                 1382.0     2.015094  105.278868  47.740000  57.566415
# 5                 1674.5     2.000000  131.930000  49.781250  82.382500
# 6                 2009.5     2.000000  137.054571  50.112857  86.964571
# 7                 2357.5     2.002890  129.389017  50.082659  79.325434
# 8                 2740.0     2.002387  107.133890  51.212172  55.933652
# 9                 3150.0     2.002494  113.879800  51.097506  62.799751
# 10                3569.5     2.000000  102.502055  50.254338  52.271233
# 11                3986.0     2.002532  107.887342  51.392405  56.582278
# 12                4368.0     2.000000  118.074255  51.979133  66.102710
#
# ...

# %% [markdown]
# ## Horno 1 - Agrupación con filtro

# %%
h1_fil.groupby(h1_fil["FinishedTime"].dt.month).mean()
# Out:
#                HeatNumber  ControlMode   TapToTap    PowerOn   PowerOff  \
# FinishedTime
# 1              191.498270          2.0  90.042907  49.691349  40.381315
# 2              593.367647          2.0  85.312059  48.474118  36.858824
# 3             1033.125698          2.0  85.208659  48.467598  36.747765
# 4             1376.792929          2.0  78.955556  49.027273  29.965152
# 5             1676.899254          2.0  84.125373  50.105597  34.028731
# 6             2013.608541          2.0  83.485409  50.781851  32.731317
# 7             2357.110320          2.0  87.315658  50.794306  36.544840
# 8             2741.623269          2.0  85.812465  51.783657  34.041551
# 9             3149.052326          2.0  85.073837  52.038081  33.055814
# 10            3569.756164          2.0  86.792055  50.838630  35.967945
# 11            3982.465672          2.0  86.952239  52.365970  34.668955
# 12            4367.332215          2.0  91.163087  52.526174  38.646309
#
# ...

# %% [markdown]
# ## Horno 2 - Agrupación sin filtro

# %%
h2.groupby(h2["FinishedTime"].dt.month).mean()
# Out:
#               HeatNumber  ControlMode   TapToTap    PowerOn   PowerOff  \
# FinishedTime
# 1                  498.0     2.001005  88.458291  39.146935  49.366432
# 2                 1438.0     1.985311  80.055141  43.114463  37.294350
# 3                 2150.5     2.011111  79.670926  43.729630  36.392778
# 4                 2579.5     2.003145  89.035220  45.070126  44.147170
# 5                 2991.0     2.000000  86.856040  44.121188  43.308713
# 6                 3513.0     2.000000  78.470872  42.165677  36.657328
# 7                 4069.5     2.000000  74.224739  39.965505  34.639547
# 8                 4645.5     2.000000  72.459689  37.454498  35.360208
# 9                 5205.5     1.998155  79.308672  38.307380  41.303321
# 10                5761.0     2.000000  74.707030  37.740598  37.377680
# 11                6329.0     2.000000  72.865785  36.953968  36.173545
# 12                6886.5     2.000000  80.819526  37.206204  43.945073
#
# ...

# %% [markdown]
# ## Horno 2 - Agrupación con filtro

# %%
h2_fil.groupby(h2_fil["FinishedTime"].dt.month).mean()
# Out:
#                HeatNumber  ControlMode   TapToTap    PowerOn   PowerOff  \
# FinishedTime
# 1              540.807692     2.000000  65.414510  37.690035  27.740035
# 2             1399.830372     1.972536  62.608401  42.565913  20.141842
# 3             2146.521127     2.000000  63.902347  44.012207  19.919718
# 4             2598.357414     2.000000  62.211027  45.566540  16.668821
# 5             2991.523711     2.000000  65.471959  43.902887  21.593196
# 6             3511.390291     2.000000  63.398252  42.170097  21.293010
# 7             4070.336957     2.000000  61.399094  39.895109  21.532609
# 8             4643.294756     2.000000  61.184629  37.335986  23.880470
# 9             5207.332024     1.998035  61.719253  38.226130  23.550295
# 10            5762.265799     2.000000  60.692379  37.516171  23.197398
# 11            6327.998172     2.000000  59.819744  36.732907  23.113528
# 12            6883.895146     2.000000  62.252816  36.961942  25.321553
#
# ...

# %% [markdown]
# ### Horno 1 - Rendimiento promedio (kWh/ton)

# %%
(h1["EnergyPerChargeTon"].mean(axis = 0))
# Out:
# 310.9880492091394

# %%
(h1_fil["EnergyPerChargeTon"].mean(axis = 0))
# Out:
# 339.0276492738037

# %% [markdown]
# ### Horno 2 - Rendimiento promedio (kWh/ton)

# %%
(h2["EnergyPerChargeTon"].mean(axis = 0))
# Out:
# 309.4747346368718

# %%
(h2_fil["EnergyPerChargeTon"].mean(axis = 0))
# Out:
# 348.20573031797204

# %% [markdown]
# ### Horno 1 - TapToTap Promedio

# %%
(h1["TapToTap"].mean(axis = 0))
# Out:
# 113.75314147627378

# %%
(h1_fil["TapToTap"].mean(axis = 0))
# Out:
# 86.04774072081744

# %% [markdown]
# ### Horno 2 - TapToTap Promedio

# %%
(h2["TapToTap"].mean(axis = 0))
# Out:
# 79.88026536312866

# %%
(h2_fil["TapToTap"].mean(axis = 0))
# Out:
# 62.425607889814856

# %% [markdown]
# ### Horno 1 - Power On Promedio

# %%
(h1["PowerOn"].mean(axis = 0))
# Out:
# 49.82093585237268

# %%
(h1_fil["PowerOn"].mean(axis = 0))
# Out:
# 50.62358795051113

# %% [markdown]
# ### Horno 2 - Power On Promedio

# %%
(h2["PowerOn"].mean(axis = 0))
# Out:
# 40.255600558659204

# %%
(h2_fil["PowerOn"].mean(axis = 0))
# Out:
# 39.74053732358426

# %% [markdown]
# ---

# %% [markdown]
# ## Máximos y mínimos

# %% [markdown]
# ### Horno 1 - TapToTap Max

# %%
h1_fil.sort_values("TapToTap", ascending = False).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 3574   2020-10-17        3575            2     162.9     58.4     104.5
# 2800   2020-08-21        2801            2     162.6     58.7     103.9
# 3463   2020-10-09        3464            2     162.4     51.1     111.3
# 2933   2020-08-30        2934            2     162.0     51.4     110.6
# 159    2020-01-13         160            2     161.6     53.9     107.7
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 3574           0    35.850215          0        4  ...                 1
# 2800           0    36.100861          0        4  ...                 1
# 3463           0    31.465517          0        4  ...                 1
# 2933           0    31.728395          0        4  ...                 1
# 159            0    33.353960          0        4  ...                 1
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %% [markdown]
# ### Horno 1 - TapToTap Min

# %%
h1_fil.sort_values("TapToTap", ascending = True).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 3879   2020-11-07        3880            2      63.8     48.4      15.4
# 2148   2020-06-26        2149            2      63.8     49.3      14.5
# 2043   2020-06-19        2044            2      63.8     48.1      15.7
# 2704   2020-08-14        2705            2      63.8     46.3      17.5
# 338    2020-01-29         339            2      63.8     48.0      15.8
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 3879           0    75.862069          0        4  ...                 1
# 2148           0    77.272727          0        4  ...                 1
# 2043           0    75.391850          0        4  ...                 1
# 2704           0    72.570533          0        4  ...                 1
# 338            0    75.235110          0        3  ...                 1
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %% [markdown]
# ### Horno 2 - TapToTap Max

# %%
h2_fil.sort_values("TapToTap", ascending = False).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 5370   2020-09-25        5371            2     129.6     38.7      90.9
# 6691   2020-12-05        6692            2     129.0     41.1      87.9
# 6376   2020-11-16        6377            2     128.4     37.0      91.4
# 3400   2020-06-09        3401            2     128.2     44.2      84.0
# 543    2020-01-18         544            2     128.2     39.0      89.2
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 5370           0    29.861111          0        3  ...                 2
# 6691           0    31.860465          0        3  ...                 2
# 6376           0    28.816199          0        3  ...                 2
# 3400           0    34.477379          0        3  ...                 2
# 543            0    30.421217          0        3  ...                 1
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %% [markdown]
# ### Horno 2 - TapToTap Min

# %%
h2_fil.sort_values("TapToTap", ascending = True).head()
# Out:
#      FinishedTime  HeatNumber  ControlMode  TapToTap  PowerOn  PowerOff  \
# 1003   2020-02-01        1004            2      32.5     27.5       5.0
# 5154   2020-09-14        5155            2      37.7     28.9       8.8
# 6137   2020-11-04        6138            2      38.9     30.7       8.2
# 6352   2020-11-15        6353            2      41.0     31.8       9.2
# 6128   2020-11-04        6129            2      41.3     32.9       8.4
#
#       Turnaround  Utilization  IsPartial  Charges  ...  AutoLowerProfile  \
# 1003           0    84.615385          0        3  ...                 1
# 5154           0    76.657825          0        4  ...                 2
# 6137           0    78.920308          0        3  ...                 2
# 6352           0    77.560976          0        3  ...                 2
# 6128           0    79.661017          0        3  ...                 2
#
#       CaveInProfile  ExtLoopProfile  IntegralProfile  IOFiltersProfile  \
# ...

# %%
#pd.set_option("max_rows", None)
print(h2_fil.loc[1003]["HeatNumber":"HeatAvgMW"])
# Out:
# HeatNumber                       1004
# ControlMode                         2
# TapToTap                         32.5
# PowerOn                          27.5
# PowerOff                            5
# Turnaround                          0
# Utilization                   84.6154
# IsPartial                           0
# Charges                             3
# ShadowModePwrOnPercent        100.004
# ControlSmartARCPercent            100
# ControlPowerProgramPercent          0
# ControlManualPercent                0
# HeatAvgMW                     117.142
# Name: 1003, dtype: object

# %%
h2_fil["HeatAvgMW"].mean()
# Out:
# 80.7861222307465

# %%
h1_fil.to_csv("C:/Users/LLerma/Google Drive/Analisis de Datos/M3 - Introduccion a Python/Files/My_files/h1_fil.csv")

# %%
h2_fil.to_csv("C:/Users/LLerma/Google Drive/Analisis de Datos/M3 - Introduccion a Python/Files/My_files/h2_fil.csv")

# %% [markdown]
# ---

# %%
h2["PowerOff"].mean()
# Out:
# 39.94596368715072

# %%
h2_fil["PowerOff"].mean()
# Out:
# 22.72460465907166

# %%
h1["EnergyPerHeat"].std()
# Out:
# 7.297328915248393

# %%
h1_fil["EnergyPerHeat"].std()
# Out:
# 3.186469506042975
