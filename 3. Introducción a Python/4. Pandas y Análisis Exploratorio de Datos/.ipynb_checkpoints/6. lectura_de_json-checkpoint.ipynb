# %% [markdown]
# ## Ejemplo 6: Lectura de JSON
#
# ### 1. Objetivos:
#     - Aprender a leer archivos JSON y crear `DataFrames` con ellos
#
# ---
#
# ### 2. Desarrollo:

# %%
import pandas as pd

# %% [markdown]
# Primero tenemos que importar la librería `json` que nos ayuda a lidiar con formato JSON en Python:

# %%
import json

# %% [markdown]
# Después leemos el archivo JSON usando `open`:

# %%
f = open('C:/Users/LLerma/Google Drive/Analisis de Datos/M3 - Introduccion a Python/Files/zomato_reviews-clean.json', 'r')

# %% [markdown]
# La ruta (o `path`) puede ser absoluto o relativo (en el Prework hay un link donde se explica esto con más claridad). El `'r'` significa que queremos leer el archivo (`read`).

# %% [markdown]
# Después convertimos nuestro archivo JSON en un diccionario de Python:

# %%
json_data = json.load(f)

# %% [markdown]
# Después cerramos nuestro archivo:

# %%
f.close()

# %% [markdown]
# Y finalmente pasamos el diccionario a `pandas.DataFrame.from_dict` para crear un `DataFrame`:

# %%
json_data
# Out:
# {'has_online_delivery': {'0': 1,
#   '1': 0,
#   '2': 1,
#   '3': 0,
#   '4': 0,
#   '5': 1,
#   '6': 0,
#   '7': 0,
#   '8': 0,
#   '9': 1,
#   '10': 0,
#   '11': 0,
#   '12': 0,
#   '13': 1,
#   '14': 0,
#   '15': 0,
#   '16': 0,
#   '17': 0,
#   '18': 1,
#   '19': 0,
#   '20': 0,
#   '21': 1,
#   '22': 0,
#   '23': 1,
#   '24': 0,
#   '25': 0,
#   '26': 1,
#   '27': 1,
#   '28': 0,
#   '29': 1,
#   '30': 1,
#   '31': 0,
#   '32': 0,
#   '33': 0,
#   '34': 0,
#   '35': 1,
#   '36': 1,
#   '37': 0,
#   '38': 0,
#   '39': 0,
#   '40': 0,
#   '41': 1,
#   '42': 1,
#   '43': 0,
#   '44': 0,
#   '45': 0,
#   '46': 0,
#   '47': 0,
#   '48': 0,
#   '49': 1,
#   '50': 0,
#   '51': 1,
#   '52': 0,
#   '53': 0,
#   '54': 1,
#   '55': 0,
#   '56': 1,
#   '57': 1,
#   '58': 0,
#   '59': 0,
#   '60': 0,
#   '61': 0,
#   '62': 1,
#   '63': 0,
#   '64': 1,
#   '65': 0,
#   '66': 0,
#   '67': 0,
#   '68': 0,
#   '69': 0,
#   '70': 1,
#   '71': 0,
#   '72': 1,
#   '73': 0,
#   '74': 0,
#   '75': 0,
#   '76': 1,
#   '77': 1,
#   '78': 1,
#   '79': 0,
#   '80': 0,
#   '81': 0,
#   '82': 1,
#   '83': 0,
#   '84': 0,
#   '85': 0,
#   '86': 0,
#   '87': 0,
#   '88': 0,
#   '89': 0,
#   '90': 0,
#   '91': 1,
#   '92': 0,
#   '93': 1,
#   '94': 0,
#   '95': 1,
#   '96': 1,
#   '97': 1,
#   '98': 0,
#   '99': 1,
#   '100': 0,
#   '101': 1,
#   '102': 0,
#   '103': 1,
#   '104': 0,
#   '105': 0,
#   '106': 0,
#   '107': 0,
#   '108': 0,
#   '109': 1,
#   '110': 0,
#   '111': 1,
#   '112': 1,
#   '113': 0,
#   '114': 0,
#   '115': 1,
#   '116': 1,
#   '117': 1,
#   '118': 0,
#   '119': 0,
#   '120': 0,
#   '121': 0,
#   '122': 1,
#   '123': 1,
#   '124': 1,
#   '125': 0,
#   '126': 1,
#   '127': 1,
#   '128': 0,
#   '129': 1,
#   '130': 0,
#   '131': 0,
#   '132': 1,
#   '133': 1,
#   '134': 1,
#   '135': 1,
#   '136': 1,
#   '137': 0,
#   '138': 1,
#   '139': 1,
#   '140': 0,
#   '141': 0,
#   '142': 0,
#   '143': 0,
#   '144': 0,
#   '145': 0,
#   '146': 0,
#   '147': 0,
#   '148': 0,
#   '149': 0,
#   '150': 0,
#   '151': 0,
#   '152': 0,
#   '153': 0,
#   '154': 0,
#   '155': 0,
#   '156': 0,
#   '157': 0,
#   '158': 0,
#   '159': 0,
#   '160': 1,
#   '161': 0,
#   '162': 0,
#   '163': 0,
#   '164': 0,
#   '165': 1,
#   '166': 0,
#   '167': 1,
#   '168': 1,
#   '169': 0,
#   '170': 0,
#   '171': 0,
#   '172': 0,
#   '173': 0,
#   '174': 0,
#   '175': 0,
#   '176': 0,
#   '177': 0,
#   '178': 1,
#   '179': 0,
#   '180': 0,
#   '181': 0,
#   '182': 0,
#   '183': 1,
#   '184': 0,
#   '185': 0,
#   '186': 1,
#   '187': 1,
#   '188': 1,
#   '189': 1,
#   '190': 0,
#   '191': 1,
#   '192': 1,
#   '193': 1,
#   '194': 0,
#   '195': 0,
#   '196': 1,
#   '197': 0,
#   '198': 0,
#   '199': 1,
#   '200': 1,
#   '201': 1,
#   '202': 1,
#   '203': 1,
#   '204': 0,
#   '205': 0,
#   '206': 1,
#   '207': 1,
#   '208': 0,
#   '209': 1,
#   '210': 1,
#   '211': 0,
#   '212': 0,
#   '213': 0,
#   '214': 0,
#   '215': 1,
#   '216': 1,
#   '217': 0,
#   '218': 0,
#   '219': 0,
#   '220': 0,
#   '221': 0,
#   '222': 1,
#   '223': 1,
#   '224': 0,
#   '225': 0,
#   '226': 0,
#   '227': 1,
#   '228': 0,
#   '229': 0,
#   '230': 0,
#   '231': 1,
#   '232': 1,
#   '233': 0,
#   '234': 0,
#   '235': 1,
#   '236': 0,
#   '237': 0,
#   '238': 1,
#   '239': 0,
#   '240': 0,
#   '241': 0,
#   '242': 0,
#   '243': 0,
#   '244': 0,
#   '245': 0,
#   '246': 0,
#   '247': 0,
#   '248': 0,
#   '249': 0,
#   '250': 0,
#   '251': 0,
#   '252': 0,
#   '253': 0,
#   '254': 0,
#   '255': 0,
#   '256': 0,
#   '257': 0,
#   '258': 0,
#   '259': 0,
#   '260': 0,
#   '261': 0,
#   '262': 0,
#   '263': 0,
#   '264': 0,
#   '265': 0,
#   '266': 0,
#   '267': 0,
#   '268': 0,
#   '269': 0,
#   '270': 0,
#   '271': 0,
#   '272': 0,
#   '273': 0,
#   '274': 0,
#   '275': 0,
#   '276': 0,
#   '277': 0,
#   '278': 0,
#   '279': 0,
#   '280': 0,
#   '281': 0,
#   '282': 0,
#   '283': 0,
#   '284': 0,
#   '285': 0,
#   '286': 0,
#   '287': 0,
#   '288': 0,
#   '289': 0,
#   '290': 0,
#   '291': 0,
#   '292': 0,
#   '293': 0,
#   '294': 0,
#   '295': 0,
#   '296': 0,
#   '297': 0,
#   '298': 0,
#   '299': 0,
#   '300': 0,
#   '301': 0,
#   '302': 0,
#   '303': 0,
#   '304': 0,
#   '305': 0,
#   '306': 0,
#   '307': 0,
#   '308': 0,
#   '309': 0,
#   '310': 0,
#   '311': 0,
#   '312': 0,
#   '313': 0,
#   '314': 0,
#   '315': 0,
#   '316': 0,
#   '317': 0,
#   '318': 0,
#   '319': 0,
#   '320': 0,
#   '321': 0,
#   '322': 0,
#   '323': 0,
#   '324': 0,
#   '325': 0,
#   '326': 0,
#   '327': 0,
#   '328': 0,
#   '329': 0,
#   '330': 0,
#   '331': 0,
#   '332': 0,
#   '333': 0,
#   '334': 0,
#   '335': 0,
#   '336': 0,
#   '337': 0,
#   '338': 0,
#   '339': 0,
#   '340': 0,
#   '341': 0,
#   '342': 0,
#   '343': 0,
#   '344': 0,
#   '345': 0,
#   '346': 0,
#   '347': 0,
#   '348': 0,
#   '349': 0,
#   '350': 0,
#   '351': 0,
#   '352': 0,
#   '353': 0,
#   '354': 0,
#   '355': 0,
#   '356': 0,
#   '357': 0,
#   '358': 0,
#   '359': 0,
#   '360': 0,
#   '361': 0,
#   '362': 0,
#   '363': 0,
#   '364': 0,
#   '365': 0,
#   '366': 0,
#   '367': 0,
#   '368': 0,
#   '369': 0,
#   '370': 0,
#   '371': 0,
#   '372': 0,
#   '373': 0,
#   '374': 0,
#   '375': 0,
#   '376': 0,
#   '377': 0,
#   '378': 0,
#   '379': 0,
#   '380': 0,
#   '381': 0,
#   '382': 0,
#   '383': 0,
#   '384': 0,
#   '385': 0,
#   '386': 0,
#   '387': 0,
#   '388': 0,
#   '389': 0,
#   '390': 0,
#   '391': 0,
#   '392': 0,
#   '393': 0,
#   '394': 0,
#   '395': 0,
#   '396': 0,
#   '397': 0,
#   '398': 0,
#   '399': 0,
#   '400': 0,
#   '401': 0,
#   '402': 0,
#   '403': 0,
#   '404': 0,
#   '405': 0,
#   '406': 0,
#   '407': 0,
#   '408': 0,
#   '409': 0,
#   '410': 0,
#   '411': 0,
#   '412': 0,
#   '413': 0,
#   '414': 0,
#   '415': 0,
#   '416': 0,
#   '417': 0,
#   '418': 0,
#   '419': 0,
#   '420': 0,
#   '421': 0,
#   '422': 0,
#   '423': 0,
#   '424': 0,
#   '425': 0,
#   '426': 0,
#   '427': 0,
#   '428': 0,
#   '429': 0,
#   '430': 0,
#   '431': 0,
#   '432': 0,
#   '433': 0,
#   '434': 0,
#   '435': 0,
#   '436': 0,
#   '437': 0,
#   '438': 0,
#   '439': 0,
#   '440': 0,
#   '441': 0,
#   '442': 0,
#   '443': 0,
#   '444': 0,
#   '445': 0,
#   '446': 0,
#   '447': 0,
#   '448': 0,
#   '449': 0,
#   '450': 0,
#   '451': 0,
#   '452': 0,
#   '453': 0,
#   '454': 0,
#   '455': 0,
#   '456': 0,
#   '457': 0,
#   '458': 0,
#   '459': 0,
#   '460': 0,
#   '461': 0,
#   '462': 0,
#   '463': 0,
#   '464': 0,
#   '465': 0,
#   '466': 0,
#   '467': 0,
#   '468': 0,
#   '469': 0,
#   '470': 0,
#   '471': 0,
#   '472': 0,
#   '473': 0,
#   '474': 0,
#   '475': 0,
#   '476': 0,
#   '477': 0,
#   '478': 0,
#   '479': 0,
#   '480': 0,
#   '481': 0,
#   '482': 0,
#   '483': 0,
#   '484': 0,
#   '485': 0,
#   '486': 0,
#   '487': 0,
#   '488': 0,
#   '489': 0,
#   '490': 0,
#   '491': 0,
#   '492': 0,
#   '493': 0,
#   '494': 0,
#   '495': 0,
#   '496': 0,
#   '497': 0,
#   '498': 0,
#   '499': 0,
#   '500': 0,
#   '501': 1,
#   '502': 0,
#   '503': 1,
#   '504': 1,
#   '505': 0,
#   '506': 0,
#   '507': 0,
#   '508': 0,
#   '509': 0,
#   '510': 1,
#   '511': 0,
#   '512': 1,
#   '513': 0,
#   '514': 0,
#   '515': 0,
#   '516': 0,
#   '517': 1,
#   '518': 0,
#   '519': 1,
#   '520': 0,
#   '521': 0,
#   '522': 0,
#   '523': 0,
#   '524': 0,
#   '525': 0,
#   '526': 0,
#   '527': 0,
#   '528': 0,
#   '529': 0,
#   '530': 0,
#   '531': 0,
#   '532': 0,
#   '533': 0,
#   '534': 0,
#   '535': 0,
#   '536': 0,
#   '537': 0,
#   '538': 0,
#   '539': 0,
#   '540': 0,
#   '541': 0,
#   '542': 0,
#   '543': 0,
#   '544': 0,
#   '545': 0,
#   '546': 0,
#   '547': 0,
#   '548': 0,
#   '549': 0,
#   '550': 0,
#   '551': 0,
#   '552': 0,
#   '553': 0,
#   '554': 0,
#   '555': 0,
#   '556': 0,
#   '557': 0,
#   '558': 0,
#   '559': 0,
#   '560': 0,
#   '561': 1,
#   '562': 0,
#   '563': 0,
#   '564': 1,
#   '565': 1,
#   '566': 1,
#   '567': 1,
#   '568': 0,
#   '569': 0,
#   '570': 1,
#   '571': 0,
#   '572': 0,
#   '573': 1,
#   '574': 0,
#   '575': 0,
#   '576': 0,
#   '577': 1,
#   '578': 1,
#   '579': 1,
#   '580': 0,
#   '581': 0,
#   '582': 0,
#   '583': 0,
#   '584': 0,
#   '585': 0,
#   '586': 0,
#   '587': 0,
#   '588': 0,
#   '589': 0,
#   '590': 0,
#   '591': 0,
#   '592': 0,
#   '593': 0,
#   '594': 0,
#   '595': 0,
#   '596': 0,
#   '597': 0,
#   '598': 0,
#   '599': 0,
#   '600': 0,
#   '601': 0,
#   '602': 0,
#   '603': 0,
#   '604': 0,
#   '605': 0,
#   '606': 0,
#   '607': 0,
#   '608': 0,
#   '609': 0,
#   '610': 0,
#   '611': 0,
#   '612': 0,
#   '613': 0,
#   '614': 0,
#   '615': 0,
#   '616': 0,
#   '617': 0,
#   '618': 0,
#   '619': 0,
#   '620': 0,
#   '621': 0,
#   '622': 0,
#   '623': 0,
#   '624': 0,
#   '625': 0,
#   '626': 0,
#   '627': 0,
#   '628': 0,
#   '629': 0,
#   '630': 0,
#   '631': 0,
#   '632': 0,
#   '633': 0,
#   '634': 0,
#   '635': 0,
#   '636': 0,
#   '637': 0,
#   '638': 0,
#   '639': 0,
#   '640': 0,
#   '641': 0,
#   '642': 0,
#   '643': 0,
#   '644': 0,
#   '645': 0,
#   '646': 0,
#   '647': 0,
#   '648': 0,
#   '649': 0,
#   '650': 0,
#   '651': 0,
#   '652': 0,
#   '653': 0,
#   '654': 0,
#   '655': 0,
#   '656': 0,
#   '657': 0,
#   '658': 0,
#   '659': 0,
#   '660': 0,
#   '661': 0,
#   '662': 0,
#   '663': 0,
#   '664': 0,
#   '665': 0,
#   '666': 0,
#   '667': 0,
#   '668': 0,
#   '669': 0,
#   '670': 0,
#   '671': 0,
#   '672': 0,
#   '673': 0,
#   '674': 0,
#   '675': 0,
#   '676': 0,
#   '677': 0,
#   '678': 0,
#   '679': 0,
#   '680': 0,
#   '681': 0,
#   '682': 0,
#   '683': 0,
#   '684': 0,
#   '685': 0,
#   '686': 0,
#   '687': 0,
#   '688': 0,
#   '689': 0,
#   '690': 0,
#   '691': 0,
#   '692': 0,
#   '693': 0,
#   '694': 0,
#   '695': 0,
#   '696': 0,
#   '697': 0,
#   '698': 0,
#   '699': 0,
#   '700': 0,
#   '701': 0,
#   '702': 0,
#   '703': 0,
#   '704': 0,
#   '705': 0,
#   '706': 0,
#   '707': 0,
#   '708': 0,
#   '709': 0,
#   '710': 0,
#   '711': 0,
#   '712': 0,
#   '713': 0,
#   '714': 0,
#   '715': 0,
#   '716': 0,
#   '717': 0,
#   '718': 0,
#   '719': 0,
#   '720': 1,
#   '721': 0,
#   '722': 0,
#   '723': 0,
#   '724': 0,
#   '725': 1,
#   '726': 0,
#   '727': 0,
#   '728': 0,
#   '729': 0,
#   '730': 0,
#   '731': 1,
#   '732': 0,
#   '733': 0,
#   '734': 0,
#   '735': 1,
#   '736': 1,
#   '737': 1,
#   '738': 0,
#   '739': 0,
#   '740': 0,
#   '741': 0,
#   '742': 0,
#   '743': 0,
#   '744': 0,
#   '745': 0,
#   '746': 0,
#   '747': 0,
#   '748': 0,
#   '749': 0,
#   '750': 0,
#   '751': 0,
#   '752': 0,
#   '753': 0,
#   '754': 0,
#   '755': 0,
#   '756': 0,
#   '757': 0,
#   '758': 0,
#   '759': 0,
#   '760': 0,
#   '761': 0,
#   '762': 0,
#   '763': 1,
#   '764': 1,
#   '765': 1,
#   '766': 1,
#   '767': 0,
#   '768': 1,
#   '769': 0,
#   '770': 0,
#   '771': 1,
#   '772': 1,
#   '773': 1,
#   '774': 0,
#   '775': 1,
#   '776': 1,
#   '777': 0,
#   '778': 1,
#   '779': 0,
#   '780': 1,
#   '781': 0,
#   '782': 0,
#   '783': 0,
#   '784': 0,
#   '785': 1,
#   '786': 1,
#   '787': 0,
#   '788': 1,
#   '789': 0,
#   '790': 1,
#   '791': 1,
#   '792': 1,
#   '793': 0,
#   '794': 1,
#   '795': 1,
#   '796': 1,
#   '797': 1,
#   '798': 0,
#   '799': 0,
#   '800': 0,
#   '801': 0,
#   '802': 0,
#   '803': 0,
#   '804': 0,
#   '805': 0,
#   '806': 0,
#   '807': 0,
#   '808': 0,
#   '809': 0,
#   '810': 0,
#   '811': 0,
#   '812': 0,
#   '813': 0,
#   '814': 0,
#   '815': 0,
#   '816': 0,
#   '817': 0,
#   '818': 0,
#   '819': 0,
#   '820': 0,
#   '821': 0,
#   '822': 0,
#   '823': 0,
#   '824': 0,
#   '825': 0,
#   '826': 0,
#   '827': 0,
#   '828': 0,
#   '829': 0,
#   '830': 0,
#   '831': 0,
#   '832': 0,
#   '833': 0,
#   '834': 0,
#   '835': 0,
#   '836': 0,
#   '837': 0,
#   '838': 0,
#   '839': 0,
#   '840': 0,
#   '841': 0,
#   '842': 0,
#   '843': 0,
#   '844': 0,
#   '845': 0,
#   '846': 0,
#   '847': 0,
#   '848': 0,
#   '849': 0,
#   '850': 0,
#   '851': 0,
#   '852': 0,
#   '853': 0,
#   '854': 0,
#   '855': 0,
#   '856': 0,
#   '857': 0,
#   '858': 0,
#   '859': 0,
#   '860': 0,
#   '861': 0,
#   '862': 0,
#   '863': 0,
#   '864': 0,
#   '865': 0,
#   '866': 0,
#   '867': 0,
#   '868': 0,
#   '869': 0,
#   '870': 0,
#   '871': 0,
#   '872': 0,
#   '873': 0,
#   '874': 0,
#   '875': 0,
#   '876': 0,
#   '877': 0,
#   '878': 0,
#   '879': 0,
#   '880': 0,
#   '881': 0,
#   '882': 0,
#   '883': 0,
#   '884': 0,
#   '885': 0,
#   '886': 0,
#   '887': 0,
#   '888': 0,
#   '889': 0,
#   '890': 0,
#   '891': 0,
#   '892': 0,
#   '893': 0,
#   '894': 0,
#   '895': 0,
#   '896': 0,
#   '897': 0,
#   '898': 0,
#   '899': 0,
#   '900': 0,
#   '901': 0,
#   '902': 0,
#   '903': 0,
#   '904': 0,
#   '905': 0,
#   '906': 0,
#   '907': 0,
#   '908': 0,
#   '909': 0,
#   '910': 0,
#   '911': 0,
#   '912': 0,
#   '913': 0,
#   '914': 0,
#   '915': 0,
#   '916': 0,
#   '917': 0,
#   '918': 0,
#   '919': 0,
#   '920': 0,
#   '921': 0,
#   '922': 0,
#   '923': 0,
#   '924': 0,
#   '925': 0,
#   '926': 0,
#   '927': 0,
#   '928': 0,
#   '929': 0,
#   '930': 0,
#   '931': 0,
#   '932': 0,
#   '933': 0,
#   '934': 0,
#   '935': 0,
#   '936': 0,
#   '937': 0,
#   '938': 0,
#   '939': 0,
#   '940': 0,
#   '941': 0,
#   '942': 0,
#   '943': 0,
#   '944': 0,
#   '945': 0,
#   '946': 0,
#   '947': 0,
#   '948': 0,
#   '949': 0,
#   '950': 0,
#   '951': 0,
#   '952': 0,
#   '953': 0,
#   '954': 0,
#   '955': 0,
#   '956': 0,
#   '957': 0,
#   '958': 0,
#   '959': 0,
#   '960': 0,
#   '961': 0,
#   '962': 0,
#   '963': 0,
#   '964': 0,
#   '965': 0,
#   '966': 0,
#   '967': 0,
#   '968': 0,
#   '969': 0,
#   '970': 0,
#   '971': 0,
#   '972': 0,
#   '973': 0,
#   '974': 0,
#   '975': 0,
#   '976': 0,
#   '977': 0,
#   '978': 0,
#   '979': 0,
#   '980': 0,
#   '981': 0,
#   '982': 0,
#   '983': 0,
#   '984': 0,
#   '985': 0,
#   '986': 0,
#   '987': 0,
#   '988': 0,
#   '989': 0,
#   '990': 0,
#   '991': 0,
#   '992': 0,
#   '993': 0,
#   '994': 0,
#   '995': 0,
#   '996': 0,
#   '997': 0,
#   '998': 0,
#   '999': 0,
#   ...},
#  'price_range': {'0': 3,
#   '1': 3,
#   '2': 2,
#   '3': 3,
#   '4': 3,
#   '5': 2,
#   '6': 4,
#   '7': 4,
#   '8': 4,
#   '9': 3,
#   '10': 2,
#   '11': 4,
#   '12': 3,
#   '13': 3,
#   '14': 3,
#   '15': 3,
#   '16': 3,
#   '17': 3,
#   '18': 2,
#   '19': 3,
#   '20': 3,
#   '21': 3,
#   '22': 3,
#   '23': 3,
#   '24': 3,
#   '25': 3,
#   '26': 3,
#   '27': 3,
#   '28': 3,
#   '29': 3,
#   '30': 2,
#   '31': 3,
#   '32': 2,
#   '33': 3,
#   '34': 3,
#   '35': 2,
#   '36': 3,
#   '37': 3,
#   '38': 3,
#   '39': 3,
#   '40': 3,
#   '41': 3,
#   '42': 3,
#   '43': 3,
#   '44': 3,
#   '45': 3,
#   '46': 3,
#   '47': 2,
#   '48': 3,
#   '49': 3,
#   '50': 2,
#   '51': 3,
#   '52': 3,
#   '53': 3,
#   '54': 2,
#   '55': 2,
#   '56': 2,
#   '57': 3,
#   '58': 3,
#   '59': 3,
#   '60': 3,
#   '61': 4,
#   '62': 2,
#   '63': 2,
#   '64': 3,
#   '65': 3,
#   '66': 3,
#   '67': 2,
#   '68': 3,
#   '69': 2,
#   '70': 2,
#   '71': 3,
#   '72': 1,
#   '73': 3,
#   '74': 3,
#   '75': 2,
#   '76': 4,
#   '77': 3,
#   '78': 3,
#   '79': 3,
#   '80': 3,
#   '81': 3,
#   '82': 2,
#   '83': 3,
#   '84': 3,
#   '85': 3,
#   '86': 3,
#   '87': 2,
#   '88': 3,
#   '89': 3,
#   '90': 3,
#   '91': 2,
#   '92': 3,
#   '93': 3,
#   '94': 3,
#   '95': 4,
#   '96': 3,
#   '97': 4,
#   '98': 3,
#   '99': 3,
#   '100': 3,
#   '101': 3,
#   '102': 3,
#   '103': 3,
#   '104': 3,
#   '105': 3,
#   '106': 3,
#   '107': 3,
#   '108': 3,
#   '109': 3,
#   '110': 3,
#   '111': 3,
#   '112': 2,
#   '113': 2,
#   '114': 3,
#   '115': 4,
#   '116': 2,
#   '117': 3,
#   '118': 2,
#   '119': 2,
#   '120': 3,
#   '121': 3,
#   '122': 2,
#   '123': 3,
#   '124': 3,
#   '125': 2,
#   '126': 2,
#   '127': 2,
#   '128': 3,
#   '129': 3,
#   '130': 1,
#   '131': 4,
#   '132': 2,
#   '133': 2,
#   '134': 2,
#   '135': 1,
#   '136': 3,
#   '137': 3,
#   '138': 2,
#   '139': 3,
#   '140': 3,
#   '141': 4,
#   '142': 3,
#   '143': 3,
#   '144': 2,
#   '145': 1,
#   '146': 3,
#   '147': 3,
#   '148': 2,
#   '149': 4,
#   '150': 2,
#   '151': 3,
#   '152': 2,
#   '153': 3,
#   '154': 2,
#   '155': 1,
#   '156': 2,
#   '157': 3,
#   '158': 3,
#   '159': 2,
#   '160': 2,
#   '161': 2,
#   '162': 1,
#   '163': 2,
#   '164': 3,
#   '165': 1,
#   '166': 3,
#   '167': 2,
#   '168': 3,
#   '169': 2,
#   '170': 2,
#   '171': 3,
#   '172': 2,
#   '173': 2,
#   '174': 2,
#   '175': 1,
#   '176': 1,
#   '177': 3,
#   '178': 2,
#   '179': 2,
#   '180': 3,
#   '181': 3,
#   '182': 3,
#   '183': 2,
#   '184': 3,
#   '185': 3,
#   '186': 2,
#   '187': 3,
#   '188': 2,
#   '189': 3,
#   '190': 2,
#   '191': 4,
#   '192': 3,
#   '193': 2,
#   '194': 3,
#   '195': 4,
#   '196': 3,
#   '197': 4,
#   '198': 3,
#   '199': 2,
#   '200': 3,
#   '201': 3,
#   '202': 2,
#   '203': 1,
#   '204': 3,
#   '205': 3,
#   '206': 2,
#   '207': 3,
#   '208': 3,
#   '209': 3,
#   '210': 2,
#   '211': 3,
#   '212': 2,
#   '213': 3,
#   '214': 3,
#   '215': 2,
#   '216': 2,
#   '217': 2,
#   '218': 4,
#   '219': 3,
#   '220': 2,
#   '221': 3,
#   '222': 3,
#   '223': 2,
#   '224': 2,
#   '225': 2,
#   '226': 3,
#   '227': 2,
#   '228': 2,
#   '229': 3,
#   '230': 4,
#   '231': 1,
#   '232': 2,
#   '233': 4,
#   '234': 2,
#   '235': 2,
#   '236': 3,
#   '237': 3,
#   '238': 3,
#   '239': 3,
#   '240': 4,
#   '241': 4,
#   '242': 4,
#   '243': 4,
#   '244': 4,
#   '245': 4,
#   '246': 3,
#   '247': 3,
#   '248': 4,
#   '249': 4,
#   '250': 3,
#   '251': 4,
#   '252': 3,
#   '253': 4,
#   '254': 4,
#   '255': 3,
#   '256': 3,
#   '257': 4,
#   '258': 3,
#   '259': 4,
#   '260': 3,
#   '261': 2,
#   '262': 3,
#   '263': 4,
#   '264': 1,
#   '265': 2,
#   '266': 3,
#   '267': 4,
#   '268': 2,
#   '269': 3,
#   '270': 4,
#   '271': 2,
#   '272': 3,
#   '273': 3,
#   '274': 3,
#   '275': 3,
#   '276': 2,
#   '277': 2,
#   '278': 2,
#   '279': 4,
#   '280': 3,
#   '281': 1,
#   '282': 4,
#   '283': 4,
#   '284': 3,
#   '285': 4,
#   '286': 4,
#   '287': 3,
#   '288': 3,
#   '289': 2,
#   '290': 3,
#   '291': 3,
#   '292': 1,
#   '293': 2,
#   '294': 3,
#   '295': 3,
#   '296': 3,
#   '297': 3,
#   '298': 2,
#   '299': 2,
#   '300': 3,
#   '301': 3,
#   '302': 2,
#   '303': 2,
#   '304': 3,
#   '305': 3,
#   '306': 2,
#   '307': 3,
#   '308': 2,
#   '309': 3,
#   '310': 4,
#   '311': 3,
#   '312': 3,
#   '313': 3,
#   '314': 1,
#   '315': 2,
#   '316': 3,
#   '317': 3,
#   '318': 3,
#   '319': 2,
#   '320': 4,
#   '321': 2,
#   '322': 2,
#   '323': 3,
#   '324': 2,
#   '325': 3,
#   '326': 3,
#   '327': 3,
#   '328': 2,
#   '329': 3,
#   '330': 3,
#   '331': 3,
#   '332': 1,
#   '333': 2,
#   '334': 3,
#   '335': 4,
#   '336': 2,
#   '337': 2,
#   '338': 2,
#   '339': 2,
#   '340': 2,
#   '341': 2,
#   '342': 1,
#   '343': 2,
#   '344': 1,
#   '345': 1,
#   '346': 2,
#   '347': 2,
#   '348': 2,
#   '349': 1,
#   '350': 2,
#   '351': 3,
#   '352': 3,
#   '353': 1,
#   '354': 2,
#   '355': 3,
#   '356': 1,
#   '357': 2,
#   '358': 2,
#   '359': 1,
#   '360': 2,
#   '361': 2,
#   '362': 3,
#   '363': 3,
#   '364': 2,
#   '365': 4,
#   '366': 1,
#   '367': 4,
#   '368': 2,
#   '369': 2,
#   '370': 3,
#   '371': 1,
#   '372': 4,
#   '373': 3,
#   '374': 4,
#   '375': 4,
#   '376': 2,
#   '377': 2,
#   '378': 3,
#   '379': 3,
#   '380': 3,
#   '381': 4,
#   '382': 3,
#   '383': 3,
#   '384': 2,
#   '385': 2,
#   '386': 3,
#   '387': 1,
#   '388': 3,
#   '389': 3,
#   '390': 1,
#   '391': 3,
#   '392': 2,
#   '393': 3,
#   '394': 3,
#   '395': 3,
#   '396': 3,
#   '397': 3,
#   '398': 3,
#   '399': 2,
#   '400': 3,
#   '401': 2,
#   '402': 2,
#   '403': 1,
#   '404': 3,
#   '405': 2,
#   '406': 2,
#   '407': 2,
#   '408': 2,
#   '409': 4,
#   '410': 2,
#   '411': 2,
#   '412': 2,
#   '413': 2,
#   '414': 2,
#   '415': 2,
#   '416': 2,
#   '417': 3,
#   '418': 2,
#   '419': 2,
#   '420': 3,
#   '421': 2,
#   '422': 2,
#   '423': 2,
#   '424': 2,
#   '425': 4,
#   '426': 2,
#   '427': 1,
#   '428': 3,
#   '429': 2,
#   '430': 2,
#   '431': 2,
#   '432': 2,
#   '433': 1,
#   '434': 2,
#   '435': 2,
#   '436': 2,
#   '437': 2,
#   '438': 3,
#   '439': 2,
#   '440': 3,
#   '441': 3,
#   '442': 1,
#   '443': 2,
#   '444': 3,
#   '445': 2,
#   '446': 3,
#   '447': 1,
#   '448': 2,
#   '449': 1,
#   '450': 4,
#   '451': 1,
#   '452': 3,
#   '453': 1,
#   '454': 1,
#   '455': 2,
#   '456': 2,
#   '457': 2,
#   '458': 1,
#   '459': 3,
#   '460': 4,
#   '461': 3,
#   '462': 4,
#   '463': 2,
#   '464': 2,
#   '465': 1,
#   '466': 3,
#   '467': 2,
#   '468': 2,
#   '469': 2,
#   '470': 2,
#   '471': 2,
#   '472': 4,
#   '473': 2,
#   '474': 2,
#   '475': 1,
#   '476': 2,
#   '477': 2,
#   '478': 2,
#   '479': 3,
#   '480': 1,
#   '481': 2,
#   '482': 2,
#   '483': 2,
#   '484': 2,
#   '485': 1,
#   '486': 2,
#   '487': 2,
#   '488': 1,
#   '489': 2,
#   '490': 2,
#   '491': 2,
#   '492': 1,
#   '493': 2,
#   '494': 2,
#   '495': 1,
#   '496': 1,
#   '497': 2,
#   '498': 3,
#   '499': 3,
#   '500': 3,
#   '501': 2,
#   '502': 3,
#   '503': 3,
#   '504': 2,
#   '505': 2,
#   '506': 2,
#   '507': 3,
#   '508': 2,
#   '509': 4,
#   '510': 3,
#   '511': 2,
#   '512': 2,
#   '513': 2,
#   '514': 3,
#   '515': 2,
#   '516': 1,
#   '517': 2,
#   '518': 3,
#   '519': 2,
#   '520': 3,
#   '521': 3,
#   '522': 3,
#   '523': 3,
#   '524': 3,
#   '525': 2,
#   '526': 2,
#   '527': 4,
#   '528': 2,
#   '529': 3,
#   '530': 2,
#   '531': 2,
#   '532': 3,
#   '533': 2,
#   '534': 2,
#   '535': 2,
#   '536': 2,
#   '537': 4,
#   '538': 1,
#   '539': 2,
#   '540': 3,
#   '541': 3,
#   '542': 2,
#   '543': 2,
#   '544': 3,
#   '545': 4,
#   '546': 4,
#   '547': 3,
#   '548': 3,
#   '549': 2,
#   '550': 3,
#   '551': 3,
#   '552': 3,
#   '553': 2,
#   '554': 2,
#   '555': 3,
#   '556': 2,
#   '557': 2,
#   '558': 1,
#   '559': 2,
#   '560': 4,
#   '561': 2,
#   '562': 2,
#   '563': 2,
#   '564': 3,
#   '565': 2,
#   '566': 3,
#   '567': 2,
#   '568': 3,
#   '569': 2,
#   '570': 2,
#   '571': 1,
#   '572': 3,
#   '573': 3,
#   '574': 3,
#   '575': 3,
#   '576': 1,
#   '577': 2,
#   '578': 1,
#   '579': 2,
#   '580': 3,
#   '581': 1,
#   '582': 2,
#   '583': 3,
#   '584': 3,
#   '585': 1,
#   '586': 3,
#   '587': 1,
#   '588': 2,
#   '589': 4,
#   '590': 2,
#   '591': 2,
#   '592': 3,
#   '593': 4,
#   '594': 2,
#   '595': 2,
#   '596': 4,
#   '597': 4,
#   '598': 4,
#   '599': 3,
#   '600': 4,
#   '601': 3,
#   '602': 3,
#   '603': 3,
#   '604': 4,
#   '605': 4,
#   '606': 2,
#   '607': 4,
#   '608': 3,
#   '609': 3,
#   '610': 3,
#   '611': 4,
#   '612': 3,
#   '613': 3,
#   '614': 1,
#   '615': 3,
#   '616': 2,
#   '617': 3,
#   '618': 3,
#   '619': 3,
#   '620': 2,
#   '621': 2,
#   '622': 3,
#   '623': 2,
#   '624': 4,
#   '625': 2,
#   '626': 2,
#   '627': 3,
#   '628': 4,
#   '629': 1,
#   '630': 3,
#   '631': 2,
#   '632': 4,
#   '633': 2,
#   '634': 3,
#   '635': 1,
#   '636': 2,
#   '637': 2,
#   '638': 2,
#   '639': 3,
#   '640': 2,
#   '641': 4,
#   '642': 4,
#   '643': 2,
#   '644': 2,
#   '645': 3,
#   '646': 3,
#   '647': 4,
#   '648': 3,
#   '649': 4,
#   '650': 4,
#   '651': 3,
#   '652': 4,
#   '653': 4,
#   '654': 1,
#   '655': 4,
#   '656': 2,
#   '657': 3,
#   '658': 3,
#   '659': 1,
#   '660': 3,
#   '661': 2,
#   '662': 4,
#   '663': 2,
#   '664': 3,
#   '665': 3,
#   '666': 2,
#   '667': 3,
#   '668': 3,
#   '669': 3,
#   '670': 3,
#   '671': 1,
#   '672': 3,
#   '673': 3,
#   '674': 3,
#   '675': 1,
#   '676': 4,
#   '677': 3,
#   '678': 2,
#   '679': 2,
#   '680': 2,
#   '681': 1,
#   '682': 3,
#   '683': 1,
#   '684': 3,
#   '685': 2,
#   '686': 1,
#   '687': 2,
#   '688': 3,
#   '689': 4,
#   '690': 3,
#   '691': 2,
#   '692': 3,
#   '693': 2,
#   '694': 3,
#   '695': 2,
#   '696': 3,
#   '697': 3,
#   '698': 2,
#   '699': 4,
#   '700': 2,
#   '701': 2,
#   '702': 3,
#   '703': 2,
#   '704': 3,
#   '705': 3,
#   '706': 3,
#   '707': 2,
#   '708': 4,
#   '709': 1,
#   '710': 2,
#   '711': 3,
#   '712': 2,
#   '713': 2,
#   '714': 2,
#   '715': 2,
#   '716': 2,
#   '717': 4,
#   '718': 2,
#   '719': 3,
#   '720': 3,
#   '721': 3,
#   '722': 3,
#   '723': 3,
#   '724': 3,
#   '725': 3,
#   '726': 3,
#   '727': 3,
#   '728': 4,
#   '729': 4,
#   '730': 3,
#   '731': 3,
#   '732': 3,
#   '733': 3,
#   '734': 3,
#   '735': 2,
#   '736': 2,
#   '737': 3,
#   '738': 4,
#   '739': 3,
#   '740': 3,
#   '741': 4,
#   '742': 3,
#   '743': 3,
#   '744': 4,
#   '745': 4,
#   '746': 4,
#   '747': 4,
#   '748': 4,
#   '749': 3,
#   '750': 2,
#   '751': 4,
#   '752': 4,
#   '753': 4,
#   '754': 4,
#   '755': 4,
#   '756': 4,
#   '757': 3,
#   '758': 4,
#   '759': 4,
#   '760': 3,
#   '761': 2,
#   '762': 4,
#   '763': 3,
#   '764': 3,
#   '765': 4,
#   '766': 4,
#   '767': 3,
#   '768': 4,
#   '769': 3,
#   '770': 4,
#   '771': 4,
#   '772': 4,
#   '773': 4,
#   '774': 2,
#   '775': 3,
#   '776': 4,
#   '777': 3,
#   '778': 3,
#   '779': 2,
#   '780': 4,
#   '781': 4,
#   '782': 4,
#   '783': 4,
#   '784': 4,
#   '785': 2,
#   '786': 4,
#   '787': 4,
#   '788': 3,
#   '789': 4,
#   '790': 3,
#   '791': 4,
#   '792': 3,
#   '793': 4,
#   '794': 2,
#   '795': 2,
#   '796': 3,
#   '797': 3,
#   '798': 3,
#   '799': 2,
#   '800': 3,
#   '801': 3,
#   '802': 3,
#   '803': 3,
#   '804': 2,
#   '805': 4,
#   '806': 3,
#   '807': 2,
#   '808': 3,
#   '809': 2,
#   '810': 2,
#   '811': 3,
#   '812': 2,
#   '813': 3,
#   '814': 2,
#   '815': 3,
#   '816': 3,
#   '817': 4,
#   '818': 4,
#   '819': 3,
#   '820': 2,
#   '821': 4,
#   '822': 3,
#   '823': 2,
#   '824': 2,
#   '825': 3,
#   '826': 2,
#   '827': 4,
#   '828': 3,
#   '829': 3,
#   '830': 3,
#   '831': 4,
#   '832': 4,
#   '833': 3,
#   '834': 3,
#   '835': 4,
#   '836': 3,
#   '837': 3,
#   '838': 2,
#   '839': 2,
#   '840': 3,
#   '841': 3,
#   '842': 3,
#   '843': 3,
#   '844': 3,
#   '845': 2,
#   '846': 3,
#   '847': 2,
#   '848': 4,
#   '849': 3,
#   '850': 2,
#   '851': 3,
#   '852': 3,
#   '853': 4,
#   '854': 3,
#   '855': 2,
#   '856': 2,
#   '857': 3,
#   '858': 2,
#   '859': 3,
#   '860': 2,
#   '861': 3,
#   '862': 2,
#   '863': 3,
#   '864': 4,
#   '865': 3,
#   '866': 2,
#   '867': 4,
#   '868': 4,
#   '869': 4,
#   '870': 3,
#   '871': 2,
#   '872': 2,
#   '873': 4,
#   '874': 4,
#   '875': 3,
#   '876': 3,
#   '877': 3,
#   '878': 3,
#   '879': 2,
#   '880': 4,
#   '881': 4,
#   '882': 4,
#   '883': 4,
#   '884': 4,
#   '885': 3,
#   '886': 4,
#   '887': 4,
#   '888': 4,
#   '889': 3,
#   '890': 4,
#   '891': 3,
#   '892': 3,
#   '893': 4,
#   '894': 4,
#   '895': 2,
#   '896': 3,
#   '897': 4,
#   '898': 4,
#   '899': 4,
#   '900': 3,
#   '901': 4,
#   '902': 4,
#   '903': 4,
#   '904': 4,
#   '905': 3,
#   '906': 4,
#   '907': 3,
#   '908': 4,
#   '909': 3,
#   '910': 3,
#   '911': 3,
#   '912': 3,
#   '913': 4,
#   '914': 3,
#   '915': 4,
#   '916': 3,
#   '917': 4,
#   '918': 2,
#   '919': 3,
#   '920': 3,
#   '921': 4,
#   '922': 4,
#   '923': 4,
#   '924': 4,
#   '925': 2,
#   '926': 3,
#   '927': 2,
#   '928': 4,
#   '929': 3,
#   '930': 2,
#   '931': 3,
#   '932': 3,
#   '933': 3,
#   '934': 4,
#   '935': 3,
#   '936': 4,
#   '937': 4,
#   '938': 3,
#   '939': 2,
#   '940': 4,
#   '941': 4,
#   '942': 4,
#   '943': 4,
#   '944': 4,
#   '945': 4,
#   '946': 4,
#   '947': 4,
#   '948': 4,
#   '949': 4,
#   '950': 4,
#   '951': 3,
#   '952': 3,
#   '953': 4,
#   '954': 4,
#   '955': 4,
#   '956': 4,
#   '957': 4,
#   '958': 4,
#   '959': 3,
#   '960': 4,
#   '961': 4,
#   '962': 4,
#   '963': 4,
#   '964': 2,
#   '965': 4,
#   '966': 3,
#   '967': 2,
#   '968': 1,
#   '969': 4,
#   '970': 2,
#   '971': 4,
#   '972': 3,
#   '973': 4,
#   '974': 3,
#   '975': 2,
#   '976': 4,
#   '977': 3,
#   '978': 4,
#   '979': 1,
#   '980': 4,
#   '981': 4,
#   '982': 4,
#   '983': 4,
#   '984': 3,
#   '985': 2,
#   '986': 4,
#   '987': 3,
#   '988': 4,
#   '989': 4,
#   '990': 4,
#   '991': 4,
#   '992': 4,
#   '993': 4,
#   '994': 4,
#   '995': 4,
#   '996': 4,
#   '997': 3,
#   '998': 3,
#   '999': 2,
#   ...},
#  'currency': {'0': 'Rs.',
#   '1': 'Rs.',
#   '2': 'Rs.',
#   '3': 'Rs.',
#   '4': 'Rs.',
#   '5': 'Rs.',
#   '6': 'Rs.',
#   '7': 'Rs.',
#   '8': 'Rs.',
#   '9': 'Rs.',
#   '10': 'Rs.',
#   '11': 'Rs.',
#   '12': 'Rs.',
#   '13': 'Rs.',
#   '14': 'Rs.',
#   '15': 'Rs.',
#   '16': 'Rs.',
#   '17': 'Rs.',
#   '18': 'Rs.',
#   '19': 'Rs.',
#   '20': 'Rs.',
#   '21': 'Rs.',
#   '22': 'Rs.',
#   '23': 'Rs.',
#   '24': 'Rs.',
#   '25': 'Rs.',
#   '26': 'Rs.',
#   '27': 'Rs.',
#   '28': 'Rs.',
#   '29': 'Rs.',
#   '30': 'Rs.',
#   '31': 'Rs.',
#   '32': 'Rs.',
#   '33': 'Rs.',
#   '34': 'Rs.',
#   '35': 'Rs.',
#   '36': 'Rs.',
#   '37': 'Rs.',
#   '38': 'Rs.',
#   '39': 'Rs.',
#   '40': 'Rs.',
#   '41': 'Rs.',
#   '42': 'Rs.',
#   '43': 'Rs.',
#   '44': 'Rs.',
#   '45': 'Rs.',
#   '46': 'Rs.',
#   '47': 'Rs.',
#   '48': 'Rs.',
#   '49': 'Rs.',
#   '50': 'Rs.',
#   '51': 'Rs.',
#   '52': 'Rs.',
#   '53': 'Rs.',
#   '54': 'Rs.',
#   '55': 'Rs.',
#   '56': 'Rs.',
#   '57': 'Rs.',
#   '58': 'Rs.',
#   '59': 'Rs.',
#   '60': 'Rs.',
#   '61': 'Rs.',
#   '62': 'Rs.',
#   '63': 'Rs.',
#   '64': 'Rs.',
#   '65': 'Rs.',
#   '66': 'Rs.',
#   '67': 'Rs.',
#   '68': 'Rs.',
#   '69': 'Rs.',
#   '70': 'Rs.',
#   '71': 'Rs.',
#   '72': 'Rs.',
#   '73': 'Rs.',
#   '74': 'Rs.',
#   '75': 'Rs.',
#   '76': 'Rs.',
#   '77': 'Rs.',
#   '78': 'Rs.',
#   '79': 'Rs.',
#   '80': 'Rs.',
#   '81': 'Rs.',
#   '82': 'Rs.',
#   '83': 'Rs.',
#   '84': 'Rs.',
#   '85': 'Rs.',
#   '86': 'Rs.',
#   '87': 'Rs.',
#   '88': 'Rs.',
#   '89': 'Rs.',
#   '90': 'Rs.',
#   '91': 'Rs.',
#   '92': 'Rs.',
#   '93': 'Rs.',
#   '94': 'Rs.',
#   '95': 'Rs.',
#   '96': 'Rs.',
#   '97': 'Rs.',
#   '98': 'Rs.',
#   '99': 'Rs.',
#   '100': 'Rs.',
#   '101': 'Rs.',
#   '102': 'Rs.',
#   '103': 'Rs.',
#   '104': 'Rs.',
#   '105': 'Rs.',
#   '106': 'Rs.',
#   '107': 'Rs.',
#   '108': 'Rs.',
#   '109': 'Rs.',
#   '110': 'Rs.',
#   '111': 'Rs.',
#   '112': 'Rs.',
#   '113': 'Rs.',
#   '114': 'Rs.',
#   '115': 'Rs.',
#   '116': 'Rs.',
#   '117': 'Rs.',
#   '118': 'Rs.',
#   '119': 'Rs.',
#   '120': 'Rs.',
#   '121': 'Rs.',
#   '122': 'Rs.',
#   '123': 'Rs.',
#   '124': 'Rs.',
#   '125': 'Rs.',
#   '126': 'Rs.',
#   '127': 'Rs.',
#   '128': 'Rs.',
#   '129': 'Rs.',
#   '130': 'Rs.',
#   '131': 'Rs.',
#   '132': 'Rs.',
#   '133': 'Rs.',
#   '134': 'Rs.',
#   '135': 'Rs.',
#   '136': 'Rs.',
#   '137': 'Rs.',
#   '138': 'Rs.',
#   '139': 'Rs.',
#   '140': 'Rs.',
#   '141': 'Rs.',
#   '142': 'Rs.',
#   '143': 'Rs.',
#   '144': 'Rs.',
#   '145': 'Rs.',
#   '146': 'Rs.',
#   '147': 'Rs.',
#   '148': 'Rs.',
#   '149': 'Rs.',
#   '150': 'Rs.',
#   '151': 'Rs.',
#   '152': 'Rs.',
#   '153': 'Rs.',
#   '154': 'Rs.',
#   '155': 'Rs.',
#   '156': 'Rs.',
#   '157': 'Rs.',
#   '158': 'Rs.',
#   '159': 'Rs.',
#   '160': 'Rs.',
#   '161': 'Rs.',
#   '162': 'Rs.',
#   '163': 'Rs.',
#   '164': 'Rs.',
#   '165': 'Rs.',
#   '166': 'Rs.',
#   '167': 'Rs.',
#   '168': 'Rs.',
#   '169': 'Rs.',
#   '170': 'Rs.',
#   '171': 'Rs.',
#   '172': 'Rs.',
#   '173': 'Rs.',
#   '174': 'Rs.',
#   '175': 'Rs.',
#   '176': 'Rs.',
#   '177': 'Rs.',
#   '178': 'Rs.',
#   '179': 'Rs.',
#   '180': 'Rs.',
#   '181': 'Rs.',
#   '182': 'Rs.',
#   '183': 'Rs.',
#   '184': 'Rs.',
#   '185': 'Rs.',
#   '186': 'Rs.',
#   '187': 'Rs.',
#   '188': 'Rs.',
#   '189': 'Rs.',
#   '190': 'Rs.',
#   '191': 'Rs.',
#   '192': 'Rs.',
#   '193': 'Rs.',
#   '194': 'Rs.',
#   '195': 'Rs.',
#   '196': 'Rs.',
#   '197': 'Rs.',
#   '198': 'Rs.',
#   '199': 'Rs.',
#   '200': 'Rs.',
#   '201': 'Rs.',
#   '202': 'Rs.',
#   '203': 'Rs.',
#   '204': 'Rs.',
#   '205': 'Rs.',
#   '206': 'Rs.',
#   '207': 'Rs.',
#   '208': 'Rs.',
#   '209': 'Rs.',
#   '210': 'Rs.',
#   '211': 'Rs.',
#   '212': 'Rs.',
#   '213': 'Rs.',
#   '214': 'Rs.',
#   '215': 'Rs.',
#   '216': 'Rs.',
#   '217': 'Rs.',
#   '218': 'Rs.',
#   '219': 'Rs.',
#   '220': 'Rs.',
#   '221': 'Rs.',
#   '222': 'Rs.',
#   '223': 'Rs.',
#   '224': 'Rs.',
#   '225': 'Rs.',
#   '226': 'Rs.',
#   '227': 'Rs.',
#   '228': 'Rs.',
#   '229': 'Rs.',
#   '230': 'Rs.',
#   '231': 'Rs.',
#   '232': 'Rs.',
#   '233': 'Rs.',
#   '234': 'Rs.',
#   '235': 'Rs.',
#   '236': 'Rs.',
#   '237': 'Rs.',
#   '238': 'Rs.',
#   '239': 'Rs.',
#   '240': 'Rs.',
#   '241': 'Rs.',
#   '242': 'Rs.',
#   '243': 'Rs.',
#   '244': 'Rs.',
#   '245': 'Rs.',
#   '246': 'Rs.',
#   '247': 'Rs.',
#   '248': 'Rs.',
#   '249': 'Rs.',
#   '250': 'Rs.',
#   '251': 'Rs.',
#   '252': 'Rs.',
#   '253': 'Rs.',
#   '254': 'Rs.',
#   '255': 'Rs.',
#   '256': 'Rs.',
#   '257': 'Rs.',
#   '258': 'Rs.',
#   '259': 'Rs.',
#   '260': 'Rs.',
#   '261': 'Rs.',
#   '262': 'Rs.',
#   '263': 'Rs.',
#   '264': 'Rs.',
#   '265': 'Rs.',
#   '266': 'Rs.',
#   '267': 'Rs.',
#   '268': 'Rs.',
#   '269': 'Rs.',
#   '270': 'Rs.',
#   '271': 'Rs.',
#   '272': 'Rs.',
#   '273': 'Rs.',
#   '274': 'Rs.',
#   '275': 'Rs.',
#   '276': 'Rs.',
#   '277': 'Rs.',
#   '278': 'Rs.',
#   '279': 'Rs.',
#   '280': 'Rs.',
#   '281': 'Rs.',
#   '282': 'Rs.',
#   '283': 'Rs.',
#   '284': 'Rs.',
#   '285': 'Rs.',
#   '286': 'Rs.',
#   '287': 'Rs.',
#   '288': 'Rs.',
#   '289': 'Rs.',
#   '290': 'Rs.',
#   '291': 'Rs.',
#   '292': 'Rs.',
#   '293': 'Rs.',
#   '294': 'Rs.',
#   '295': 'Rs.',
#   '296': 'Rs.',
#   '297': 'Rs.',
#   '298': 'Rs.',
#   '299': 'Rs.',
#   '300': 'Rs.',
#   '301': 'Rs.',
#   '302': 'Rs.',
#   '303': 'Rs.',
#   '304': 'Rs.',
#   '305': 'Rs.',
#   '306': 'Rs.',
#   '307': 'Rs.',
#   '308': 'Rs.',
#   '309': 'Rs.',
#   '310': 'Rs.',
#   '311': 'Rs.',
#   '312': 'Rs.',
#   '313': 'Rs.',
#   '314': 'Rs.',
#   '315': 'Rs.',
#   '316': 'Rs.',
#   '317': 'Rs.',
#   '318': 'Rs.',
#   '319': 'Rs.',
#   '320': 'Rs.',
#   '321': 'Rs.',
#   '322': 'Rs.',
#   '323': 'Rs.',
#   '324': 'Rs.',
#   '325': 'Rs.',
#   '326': 'Rs.',
#   '327': 'Rs.',
#   '328': 'Rs.',
#   '329': 'Rs.',
#   '330': 'Rs.',
#   '331': 'Rs.',
#   '332': 'Rs.',
#   '333': 'Rs.',
#   '334': 'Rs.',
#   '335': 'Rs.',
#   '336': 'Rs.',
#   '337': 'Rs.',
#   '338': 'Rs.',
#   '339': 'Rs.',
#   '340': 'Rs.',
#   '341': 'Rs.',
#   '342': 'Rs.',
#   '343': 'Rs.',
#   '344': 'Rs.',
#   '345': 'Rs.',
#   '346': 'Rs.',
#   '347': 'Rs.',
#   '348': 'Rs.',
#   '349': 'Rs.',
#   '350': 'Rs.',
#   '351': 'Rs.',
#   '352': 'Rs.',
#   '353': 'Rs.',
#   '354': 'Rs.',
#   '355': 'Rs.',
#   '356': 'Rs.',
#   '357': 'Rs.',
#   '358': 'Rs.',
#   '359': 'Rs.',
#   '360': 'Rs.',
#   '361': 'Rs.',
#   '362': 'Rs.',
#   '363': 'Rs.',
#   '364': 'Rs.',
#   '365': 'Rs.',
#   '366': 'Rs.',
#   '367': 'Rs.',
#   '368': 'Rs.',
#   '369': 'Rs.',
#   '370': 'Rs.',
#   '371': 'Rs.',
#   '372': 'Rs.',
#   '373': 'Rs.',
#   '374': 'Rs.',
#   '375': 'Rs.',
#   '376': 'Rs.',
#   '377': 'Rs.',
#   '378': 'Rs.',
#   '379': 'Rs.',
#   '380': 'Rs.',
#   '381': 'Rs.',
#   '382': 'Rs.',
#   '383': 'Rs.',
#   '384': 'Rs.',
#   '385': 'Rs.',
#   '386': 'Rs.',
#   '387': 'Rs.',
#   '388': 'Rs.',
#   '389': 'Rs.',
#   '390': 'Rs.',
#   '391': 'Rs.',
#   '392': 'Rs.',
#   '393': 'Rs.',
#   '394': 'Rs.',
#   '395': 'Rs.',
#   '396': 'Rs.',
#   '397': 'Rs.',
#   '398': 'Rs.',
#   '399': 'Rs.',
#   '400': 'Rs.',
#   '401': 'Rs.',
#   '402': 'Rs.',
#   '403': 'Rs.',
#   '404': 'Rs.',
#   '405': 'Rs.',
#   '406': 'Rs.',
#   '407': 'Rs.',
#   '408': 'Rs.',
#   '409': 'Rs.',
#   '410': 'Rs.',
#   '411': 'Rs.',
#   '412': 'Rs.',
#   '413': 'Rs.',
#   '414': 'Rs.',
#   '415': 'Rs.',
#   '416': 'Rs.',
#   '417': 'Rs.',
#   '418': 'Rs.',
#   '419': 'Rs.',
#   '420': 'Rs.',
#   '421': 'Rs.',
#   '422': 'Rs.',
#   '423': 'Rs.',
#   '424': 'Rs.',
#   '425': 'Rs.',
#   '426': 'Rs.',
#   '427': 'Rs.',
#   '428': 'Rs.',
#   '429': 'Rs.',
#   '430': 'Rs.',
#   '431': 'Rs.',
#   '432': 'Rs.',
#   '433': 'Rs.',
#   '434': 'Rs.',
#   '435': 'Rs.',
#   '436': 'Rs.',
#   '437': 'Rs.',
#   '438': 'Rs.',
#   '439': 'Rs.',
#   '440': 'Rs.',
#   '441': 'Rs.',
#   '442': 'Rs.',
#   '443': 'Rs.',
#   '444': 'Rs.',
#   '445': 'Rs.',
#   '446': 'Rs.',
#   '447': 'Rs.',
#   '448': 'Rs.',
#   '449': 'Rs.',
#   '450': 'Rs.',
#   '451': 'Rs.',
#   '452': 'Rs.',
#   '453': 'Rs.',
#   '454': 'Rs.',
#   '455': 'Rs.',
#   '456': 'Rs.',
#   '457': 'Rs.',
#   '458': 'Rs.',
#   '459': 'Rs.',
#   '460': 'Rs.',
#   '461': 'Rs.',
#   '462': 'Rs.',
#   '463': 'Rs.',
#   '464': 'Rs.',
#   '465': 'Rs.',
#   '466': 'Rs.',
#   '467': 'Rs.',
#   '468': 'Rs.',
#   '469': 'Rs.',
#   '470': 'Rs.',
#   '471': 'Rs.',
#   '472': 'Rs.',
#   '473': 'Rs.',
#   '474': 'Rs.',
#   '475': 'Rs.',
#   '476': 'Rs.',
#   '477': 'Rs.',
#   '478': 'Rs.',
#   '479': 'Rs.',
#   '480': 'Rs.',
#   '481': 'Rs.',
#   '482': 'Rs.',
#   '483': 'Rs.',
#   '484': 'Rs.',
#   '485': 'Rs.',
#   '486': 'Rs.',
#   '487': 'Rs.',
#   '488': 'Rs.',
#   '489': 'Rs.',
#   '490': 'Rs.',
#   '491': 'Rs.',
#   '492': 'Rs.',
#   '493': 'Rs.',
#   '494': 'Rs.',
#   '495': 'Rs.',
#   '496': 'Rs.',
#   '497': 'Rs.',
#   '498': 'Rs.',
#   '499': 'Rs.',
#   '500': 'Rs.',
#   '501': 'Rs.',
#   '502': 'Rs.',
#   '503': 'Rs.',
#   '504': 'Rs.',
#   '505': 'Rs.',
#   '506': 'Rs.',
#   '507': 'Rs.',
#   '508': 'Rs.',
#   '509': 'Rs.',
#   '510': 'Rs.',
#   '511': 'Rs.',
#   '512': 'Rs.',
#   '513': 'Rs.',
#   '514': 'Rs.',
#   '515': 'Rs.',
#   '516': 'Rs.',
#   '517': 'Rs.',
#   '518': 'Rs.',
#   '519': 'Rs.',
#   '520': 'Rs.',
#   '521': 'Rs.',
#   '522': 'Rs.',
#   '523': 'Rs.',
#   '524': 'Rs.',
#   '525': 'Rs.',
#   '526': 'Rs.',
#   '527': 'Rs.',
#   '528': 'Rs.',
#   '529': 'Rs.',
#   '530': 'Rs.',
#   '531': 'Rs.',
#   '532': 'Rs.',
#   '533': 'Rs.',
#   '534': 'Rs.',
#   '535': 'Rs.',
#   '536': 'Rs.',
#   '537': 'Rs.',
#   '538': 'Rs.',
#   '539': 'Rs.',
#   '540': 'Rs.',
#   '541': 'Rs.',
#   '542': 'Rs.',
#   '543': 'Rs.',
#   '544': 'Rs.',
#   '545': 'Rs.',
#   '546': 'Rs.',
#   '547': 'Rs.',
#   '548': 'Rs.',
#   '549': 'Rs.',
#   '550': 'Rs.',
#   '551': 'Rs.',
#   '552': 'Rs.',
#   '553': 'Rs.',
#   '554': 'Rs.',
#   '555': 'Rs.',
#   '556': 'Rs.',
#   '557': 'Rs.',
#   '558': 'Rs.',
#   '559': 'Rs.',
#   '560': 'Rs.',
#   '561': 'Rs.',
#   '562': 'Rs.',
#   '563': 'Rs.',
#   '564': 'Rs.',
#   '565': 'Rs.',
#   '566': 'Rs.',
#   '567': 'Rs.',
#   '568': 'Rs.',
#   '569': 'Rs.',
#   '570': 'Rs.',
#   '571': 'Rs.',
#   '572': 'Rs.',
#   '573': 'Rs.',
#   '574': 'Rs.',
#   '575': 'Rs.',
#   '576': 'Rs.',
#   '577': 'Rs.',
#   '578': 'Rs.',
#   '579': 'Rs.',
#   '580': 'Rs.',
#   '581': 'Rs.',
#   '582': 'Rs.',
#   '583': 'Rs.',
#   '584': 'Rs.',
#   '585': 'Rs.',
#   '586': 'Rs.',
#   '587': 'Rs.',
#   '588': 'Rs.',
#   '589': 'Rs.',
#   '590': 'Rs.',
#   '591': 'Rs.',
#   '592': 'Rs.',
#   '593': 'Rs.',
#   '594': 'Rs.',
#   '595': 'Rs.',
#   '596': 'Rs.',
#   '597': 'Rs.',
#   '598': 'Rs.',
#   '599': 'Rs.',
#   '600': 'Rs.',
#   '601': 'Rs.',
#   '602': 'Rs.',
#   '603': 'Rs.',
#   '604': 'Rs.',
#   '605': 'Rs.',
#   '606': 'Rs.',
#   '607': 'Rs.',
#   '608': 'Rs.',
#   '609': 'Rs.',
#   '610': 'Rs.',
#   '611': 'Rs.',
#   '612': 'Rs.',
#   '613': 'Rs.',
#   '614': 'Rs.',
#   '615': 'Rs.',
#   '616': 'Rs.',
#   '617': 'Rs.',
#   '618': 'Rs.',
#   '619': 'Rs.',
#   '620': 'Rs.',
#   '621': 'Rs.',
#   '622': 'Rs.',
#   '623': 'Rs.',
#   '624': 'Rs.',
#   '625': 'Rs.',
#   '626': 'Rs.',
#   '627': 'Rs.',
#   '628': 'Rs.',
#   '629': 'Rs.',
#   '630': 'Rs.',
#   '631': 'Rs.',
#   '632': 'Rs.',
#   '633': 'Rs.',
#   '634': 'Rs.',
#   '635': 'Rs.',
#   '636': 'Rs.',
#   '637': 'Rs.',
#   '638': 'Rs.',
#   '639': 'Rs.',
#   '640': 'Rs.',
#   '641': 'Rs.',
#   '642': 'Rs.',
#   '643': 'Rs.',
#   '644': 'Rs.',
#   '645': 'Rs.',
#   '646': 'Rs.',
#   '647': 'Rs.',
#   '648': 'Rs.',
#   '649': 'Rs.',
#   '650': 'Rs.',
#   '651': 'Rs.',
#   '652': 'Rs.',
#   '653': 'Rs.',
#   '654': 'Rs.',
#   '655': 'Rs.',
#   '656': 'Rs.',
#   '657': 'Rs.',
#   '658': 'Rs.',
#   '659': 'Rs.',
#   '660': 'Rs.',
#   '661': 'Rs.',
#   '662': 'Rs.',
#   '663': 'Rs.',
#   '664': 'Rs.',
#   '665': 'Rs.',
#   '666': 'Rs.',
#   '667': 'Rs.',
#   '668': 'Rs.',
#   '669': 'Rs.',
#   '670': 'Rs.',
#   '671': 'Rs.',
#   '672': 'Rs.',
#   '673': 'Rs.',
#   '674': 'Rs.',
#   '675': 'Rs.',
#   '676': 'Rs.',
#   '677': 'Rs.',
#   '678': 'Rs.',
#   '679': 'Rs.',
#   '680': 'Rs.',
#   '681': 'Rs.',
#   '682': 'Rs.',
#   '683': 'Rs.',
#   '684': 'Rs.',
#   '685': 'Rs.',
#   '686': 'Rs.',
#   '687': 'Rs.',
#   '688': 'Rs.',
#   '689': 'Rs.',
#   '690': 'Rs.',
#   '691': 'Rs.',
#   '692': 'Rs.',
#   '693': 'Rs.',
#   '694': 'Rs.',
#   '695': 'Rs.',
#   '696': 'Rs.',
#   '697': 'Rs.',
#   '698': 'Rs.',
#   '699': 'Rs.',
#   '700': 'Rs.',
#   '701': 'Rs.',
#   '702': 'Rs.',
#   '703': 'Rs.',
#   '704': 'Rs.',
#   '705': 'Rs.',
#   '706': 'Rs.',
#   '707': 'Rs.',
#   '708': 'Rs.',
#   '709': 'Rs.',
#   '710': 'Rs.',
#   '711': 'Rs.',
#   '712': 'Rs.',
#   '713': 'Rs.',
#   '714': 'Rs.',
#   '715': 'Rs.',
#   '716': 'Rs.',
#   '717': 'Rs.',
#   '718': 'Rs.',
#   '719': 'Rs.',
#   '720': 'AED',
#   '721': 'AED',
#   '722': 'AED',
#   '723': 'AED',
#   '724': 'AED',
#   '725': 'AED',
#   '726': 'AED',
#   '727': 'AED',
#   '728': 'AED',
#   '729': 'AED',
#   '730': 'AED',
#   '731': 'AED',
#   '732': 'AED',
#   '733': 'AED',
#   '734': 'AED',
#   '735': 'AED',
#   '736': 'AED',
#   '737': 'AED',
#   '738': 'AED',
#   '739': 'AED',
#   '740': '$',
#   '741': '$',
#   '742': '$',
#   '743': '$',
#   '744': '$',
#   '745': '$',
#   '746': '$',
#   '747': '$',
#   '748': '$',
#   '749': '$',
#   '750': '$',
#   '751': '$',
#   '752': '$',
#   '753': '$',
#   '754': '$',
#   '755': '$',
#   '756': '$',
#   '757': '$',
#   '758': '$',
#   '759': '$',
#   '760': 'AED',
#   '761': 'AED',
#   '762': 'AED',
#   '763': 'AED',
#   '764': 'AED',
#   '765': 'AED',
#   '766': 'AED',
#   '767': 'AED',
#   '768': 'AED',
#   '769': 'AED',
#   '770': 'AED',
#   '771': 'AED',
#   '772': 'AED',
#   '773': 'AED',
#   '774': 'AED',
#   '775': 'AED',
#   '776': 'AED',
#   '777': 'AED',
#   '778': 'AED',
#   '779': 'AED',
#   '780': 'AED',
#   '781': 'AED',
#   '782': 'AED',
#   '783': 'AED',
#   '784': 'AED',
#   '785': 'AED',
#   '786': 'AED',
#   '787': 'AED',
#   '788': 'AED',
#   '789': 'AED',
#   '790': 'AED',
#   '791': 'AED',
#   '792': 'AED',
#   '793': 'AED',
#   '794': 'AED',
#   '795': 'AED',
#   '796': 'AED',
#   '797': 'AED',
#   '798': 'AED',
#   '799': 'AED',
#   '800': 'LKR',
#   '801': 'LKR',
#   '802': 'LKR',
#   '803': 'LKR',
#   '804': 'LKR',
#   '805': 'LKR',
#   '806': 'LKR',
#   '807': 'LKR',
#   '808': 'LKR',
#   '809': 'LKR',
#   '810': 'LKR',
#   '811': 'LKR',
#   '812': 'LKR',
#   '813': 'LKR',
#   '814': 'LKR',
#   '815': 'LKR',
#   '816': 'LKR',
#   '817': 'LKR',
#   '818': 'LKR',
#   '819': 'LKR',
#   '820': 'TL',
#   '821': 'TL',
#   '822': 'TL',
#   '823': 'TL',
#   '824': 'TL',
#   '825': 'TL',
#   '826': 'TL',
#   '827': 'TL',
#   '828': 'TL',
#   '829': 'TL',
#   '830': 'TL',
#   '831': 'TL',
#   '832': 'TL',
#   '833': 'TL',
#   '834': 'TL',
#   '835': 'TL',
#   '836': 'TL',
#   '837': 'TL',
#   '838': 'TL',
#   '839': 'TL',
#   '840': 'TL',
#   '841': 'TL',
#   '842': 'TL',
#   '843': 'TL',
#   '844': 'TL',
#   '845': 'TL',
#   '846': 'TL',
#   '847': 'TL',
#   '848': 'TL',
#   '849': 'TL',
#   '850': 'TL',
#   '851': 'TL',
#   '852': 'TL',
#   '853': 'TL',
#   '854': 'TL',
#   '855': 'TL',
#   '856': 'TL',
#   '857': 'TL',
#   '858': 'TL',
#   '859': 'TL',
#   '860': '£',
#   '861': '£',
#   '862': '£',
#   '863': '£',
#   '864': '£',
#   '865': '£',
#   '866': '£',
#   '867': '£',
#   '868': '£',
#   '869': '£',
#   '870': '£',
#   '871': '£',
#   '872': '£',
#   '873': '£',
#   '874': '£',
#   '875': '£',
#   '876': '£',
#   '877': '£',
#   '878': '£',
#   '879': '£',
#   '880': 'QR',
#   '881': 'QR',
#   '882': 'QR',
#   '883': 'QR',
#   '884': 'QR',
#   '885': 'QR',
#   '886': 'QR',
#   '887': 'QR',
#   '888': 'QR',
#   '889': 'QR',
#   '890': 'QR',
#   '891': 'QR',
#   '892': 'QR',
#   '893': 'QR',
#   '894': 'QR',
#   '895': 'QR',
#   '896': 'QR',
#   '897': 'QR',
#   '898': 'QR',
#   '899': 'QR',
#   '900': 'P',
#   '901': 'P',
#   '902': 'P',
#   '903': 'P',
#   '904': 'P',
#   '905': 'P',
#   '906': 'P',
#   '907': 'P',
#   '908': 'P',
#   '909': 'P',
#   '910': 'P',
#   '911': 'P',
#   '912': 'P',
#   '913': 'P',
#   '914': 'P',
#   '915': 'P',
#   '916': 'P',
#   '917': 'P',
#   '918': 'P',
#   '919': 'P',
#   '920': 'R',
#   '921': 'R',
#   '922': 'R',
#   '923': 'R',
#   '924': 'R',
#   '925': 'R',
#   '926': 'R',
#   '927': 'R',
#   '928': 'R',
#   '929': 'R',
#   '930': 'R',
#   '931': 'R',
#   '932': 'R',
#   '933': 'R',
#   '934': 'R',
#   '935': 'R',
#   '936': 'R',
#   '937': 'R',
#   '938': 'R',
#   '939': 'R',
#   '940': 'R',
#   '941': 'R',
#   '942': 'R',
#   '943': 'R',
#   '944': 'R',
#   '945': 'R',
#   '946': 'R',
#   '947': 'R',
#   '948': 'R',
#   '949': 'R',
#   '950': 'R',
#   '951': 'R',
#   '952': 'R',
#   '953': 'R',
#   '954': 'R',
#   '955': 'R',
#   '956': 'R',
#   '957': 'R',
#   '958': 'R',
#   '959': 'R',
#   '960': 'R$',
#   '961': 'R$',
#   '962': 'R$',
#   '963': 'R$',
#   '964': 'R$',
#   '965': 'R$',
#   '966': 'R$',
#   '967': 'R$',
#   '968': 'R$',
#   '969': 'R$',
#   '970': 'R$',
#   '971': 'R$',
#   '972': 'R$',
#   '973': 'R$',
#   '974': 'R$',
#   '975': 'R$',
#   '976': 'R$',
#   '977': 'R$',
#   '978': 'R$',
#   '979': 'R$',
#   '980': 'R$',
#   '981': 'R$',
#   '982': 'R$',
#   '983': 'R$',
#   '984': 'R$',
#   '985': 'R$',
#   '986': 'R$',
#   '987': 'R$',
#   '988': 'R$',
#   '989': 'R$',
#   '990': 'R$',
#   '991': 'R$',
#   '992': 'R$',
#   '993': 'R$',
#   '994': 'R$',
#   '995': 'R$',
#   '996': 'R$',
#   '997': 'R$',
#   '998': 'R$',
#   '999': 'R$',
#   ...},
#  'name': {'0': 'Hauz Khas Social',
#   '1': 'Qubitos - The Terrace Cafe',
#   '2': 'The Hudson Cafe',
#   '3': 'Summer House Cafe',
#   '4': '38 Barracks',
#   '5': 'Spezia Bistro',
#   '6': 'Manhattan Brewery & Bar Exchange',
#   '7': 'The Wine Company',
#   '8': 'Farzi Cafe',
#   '9': 'Indian Grill Room',
#   '10': 'Cafeteria & Co.',
#   '11': 'Farzi Cafe',
#   '12': 'Molecule Air Bar',
#   '13': 'HotMess',
#   '14': 'My Bar Headquarters',
#   '15': 'FLYP@MTV',
#   '16': 'Tamasha',
#   '17': 'The Barbeque Company',
#   '18': 'Saravana Bhavan',
#   '19': 'Odeon Social',
#   '20': 'Spice Kraft',
#   '21': 'Hoppipola',
#   '22': 'Barbeque Nation',
#   '23': 'Peter Cat',
#   '24': 'Barbeque Nation',
#   '25': "What's Up",
#   '26': '6 Ballygunge Place',
#   '27': "TGI Friday's",
#   '28': 'The Irish House',
#   '29': 'Asia Kitchen by Mainland China',
#   '30': 'India Restaurant',
#   '31': 'Nawwarah',
#   '32': "Santa's Fantasea",
#   '33': 'Mumbai Local',
#   '34': 'Sigree Global Grill',
#   '35': 'BarBQ',
#   '36': 'Mocambo',
#   '37': "Gabbar's Bar & Kitchen",
#   '38': 'Ocean Grill',
#   '39': 'Flame & Grill',
#   '40': 'Farzi Cafe',
#   '41': 'The Fusion Kitchen',
#   '42': 'Tea Villa Cafe',
#   '43': 'Mumbai Vibe',
#   '44': '38 Degree East',
#   '45': 'Mirchi And Mime',
#   '46': "R' ADDA",
#   '47': 'The American Joint',
#   '48': "Grandmama's Cafe",
#   '49': 'SpiceKlub',
#   '50': 'Stacks And Racks',
#   '51': 'Tea Villa Cafe',
#   '52': 'Cafe Hydro',
#   '53': 'Tea Villa Cafe',
#   '54': "Joey's Pizza",
#   '55': "Joey's Pizza",
#   '56': 'The Rolling Pin',
#   '57': 'Tea Villa Cafe',
#   '58': '145 Kala Ghoda',
#   '59': 'The English Department Bar & Diner',
#   '60': 'Flechazo',
#   '61': 'Toit',
#   '62': 'Truffles',
#   '63': 'ECHOES Koramangala',
#   '64': 'Big Brewsky',
#   '65': 'Farzi Cafe',
#   '66': 'Koramangala Social',
#   '67': 'Onesta',
#   '68': 'Three Dots & A Dash',
#   '69': "Glen's Bakehouse",
#   '70': 'Onesta',
#   '71': "AB's - Absolute Barbecues",
#   '72': 'Eat Street',
#   '73': 'Hoot',
#   '74': 'Communiti',
#   '75': 'Onesta',
#   '76': 'The Fatty Bao - Asian Gastro Bar',
#   '77': 'Sultans of Spice',
#   '78': 'Bombay Brasserie',
#   '79': 'The Black Pearl',
#   '80': 'Farzi Cafe',
#   '81': 'Le Plaisir',
#   '82': 'Tales & Spirits',
#   '83': 'The Urban Foundry',
#   '84': 'Barbeque Ville',
#   '85': 'The Little Next Door',
#   '86': 'Apache',
#   '87': 'Kargo',
#   '88': 'Mineority By Saby',
#   '89': "Agent Jack's Bar",
#   '90': 'Teddy Boy',
#   '91': 'Sautéed Stories',
#   '92': 'Barbeque Nation',
#   '93': 'Effingut Brewerkz',
#   '94': 'The Sassy Spoon',
#   '95': '18 Degrees Resto Lounge',
#   '96': "Chili's",
#   '97': 'Effingut Brewerkz',
#   '98': 'German Bakery Wunderbar',
#   '99': 'Blue Water',
#   '100': "AB's - Absolute Barbecues",
#   '101': "Chili's",
#   '102': 'Prost Brew Pub',
#   '103': "Chili's",
#   '104': 'United Kitchens of India',
#   '105': 'Mocha Bar',
#   '106': 'Dock Forty Five',
#   '107': "AB's - Absolute Barbecues",
#   '108': "The Fisherman's Wharf",
#   '109': 'The Grand Trunk Road',
#   '110': 'Sahib’s Barbeque by Ohri’s',
#   '111': 'Exotica',
#   '112': 'Saffron Mantra',
#   '113': 'Conçu',
#   '114': "Jonathan's Kitchen - Holiday Inn Express & Suites",
#   '115': 'Olive Bistro',
#   '116': 'Pine & Dine',
#   '117': 'Heart Cup Coffee',
#   '118': 'Coffee Cup',
#   '119': 'Churrolto',
#   '120': 'Coal Barbecues',
#   '121': 'Maplai',
#   '122': 'Haunted',
#   '123': "Chili's",
#   '124': 'Basil With A Twist',
#   '125': 'Pind',
#   '126': 'That Madras Place',
#   '127': 'Palmshore',
#   '128': "AB's - Absolute Barbecues",
#   '129': 'Bombay Brasserie',
#   '130': 'Fusilli Reasons',
#   '131': 'Barbeque Nation',
#   '132': 'Palmshore',
#   '133': 'Paradise',
#   '134': 'Palmshore',
#   '135': "Writer's Cafe",
#   '136': 'Kaidi Kitchen',
#   '137': 'Ciclo Cafe',
#   '138': "Pantry d'or",
#   '139': "L'amandier",
#   '140': 'Vintage Machine',
#   '141': 'Barbeque Nation',
#   '142': 'Spice Caves',
#   '143': 'Royal Sky',
#   '144': 'The Cherry Tree Cafe',
#   '145': 'Grandson of Tunday Kababi',
#   '146': 'Bar Bar',
#   '147': 'Underdoggs Sports Bar & Grill',
#   '148': 'Dastarkhwan',
#   '149': 'L 14 - Renaissance Lucknow Hotel',
#   '150': 'The Chocolate Heaven',
#   '151': 'Colours by Royal Cafe - Royal Inn',
#   '152': 'Cappuccino Blast',
#   '153': 'Percussion',
#   '154': 'Free Spirit',
#   '155': 'Frozen Factory',
#   '156': 'Homeys Cafe',
#   '157': 'The Pebbles Bistro',
#   '158': 'The Urban Terrace',
#   '159': 'Chemistry Café',
#   '160': 'Cafe 17',
#   '161': 'Paragon',
#   '162': 'Tonico Cafe',
#   '163': 'Kashi Art Cafe',
#   '164': 'Cocoa Tree',
#   '165': 'Slice of Spice',
#   '166': 'Grand Hotel Restaurant',
#   '167': "Bloomsbury's Boutique Cafe and Artisan Bakery",
#   '168': 'Mustake Multicuisine Restaurant',
#   '169': 'French Toast',
#   '170': 'ChaiCofi',
#   '171': 'Nawras Seafood Restaurant',
#   '172': 'Aangan - Downtown Multicuisine Restaurant',
#   '173': 'Palaaram',
#   '174': 'Chiyang',
#   '175': 'Ali Baba & 41 Dishes',
#   '176': 'Ifthar',
#   '177': 'Barbeque Nation',
#   '178': 'Dhe Puttu',
#   '179': 'Thakkaaram',
#   '180': 'Blackout',
#   '181': 'The Forresta Kitchen & Bar',
#   '182': 'WTF',
#   '183': 'Tapri Central',
#   '184': 'Meraaki Kitchen',
#   '185': 'Replay',
#   '186': "Mutual's",
#   '187': 'On The House',
#   '188': 'Cafe LazyMojo',
#   '189': "Mamu's Infusion",
#   '190': 'O2- The Plant Cafe',
#   '191': 'Zolocrust - Hotel Clarks Amer',
#   '192': 'Decked Up By Garden Cafe',
#   '193': 'Calzone- Dine & Rooftop Lounge',
#   '194': 'Sky Beach',
#   '195': 'Monarch Restaurant - Holiday Inn Jaipur City Centre',
#   '196': 'Taruveda Bistro',
#   '197': 'Chao Chinese Bistro - Holiday Inn Jaipur City Centre',
#   '198': 'Chokhi Dhani',
#   '199': 'Nibs Cafe',
#   '200': 'Mocha',
#   '201': 'Blue -  Rooftop Cafe Restaurant Bistro',
#   '202': "La Pino'z Pizza",
#   '203': 'Huber & Holly',
#   '204': 'Yanki Sizzlers',
#   '205': 'Brick Kitchen',
#   '206': 'Puffizza',
#   '207': "Nini's Kitchen",
#   '208': '@Mango',
#   '209': "Fozzie's Pizzaiolo",
#   '210': 'Mazzo',
#   '211': '650 - The Global Kitchen',
#   '212': 'Swati Snacks',
#   '213': 'MoMo Café - Courtyard By Marriott',
#   '214': 'The Garden Cafe - The Fern',
#   '215': 'Kabir Restaurant',
#   '216': 'Cafe Alfresco',
#   '217': 'Cryo Lab',
#   '218': 'Patang - The Revolving Restaurant',
#   '219': 'Turquoise Villa',
#   '220': 'OvenFresh',
#   '221': "TGI Friday's",
#   '222': "Chili's",
#   '223': 'The Night Factory',
#   '224': "Uncle Jack's",
#   '225': "Karim's",
#   '226': 'Barbeque Nation',
#   '227': 'Taco Bell',
#   '228': 'Pal Dhaba',
#   '229': 'Brooklyn Central',
#   '230': 'Virgin Courtyard',
#   '231': 'Super Donuts',
#   '232': 'The Shooters Cafe',
#   '233': 'Hops n Grains',
#   '234': "Nik Baker's",
#   '235': 'Burgrill',
#   '236': 'Pirates of Grill',
#   '237': 'Kylin Experience',
#   '238': 'Midnight Chef',
#   '239': 'Mocha',
#   '240': "Britto's Bar & Restaurant",
#   '241': 'Antares',
#   '242': 'Curlies',
#   '243': 'Fat Fish',
#   '244': "Martin's Corner",
#   '245': 'Souza Lobo',
#   '246': 'Ritz Classic',
#   '247': 'Infantaria',
#   '248': 'Burger Factory',
#   '249': 'The Black Sheep Bistro',
#   '250': 'Baba Au Rhum',
#   '251': 'Club Cubana',
#   '252': 'La Plage',
#   '253': "St. Anthony's",
#   '254': "The Fisherman's Wharf",
#   '255': "Fisherman's Cove",
#   '256': 'Calamari',
#   '257': "The Fisherman's Wharf",
#   '258': 'Cafe Al Fresco by Cantina Bodega',
#   '259': 'LPK Waterfront',
#   '260': 'Mocha',
#   '261': 'Just My Bakes',
#   '262': 'KYRO',
#   '263': 'Square - Sayaji Hotel',
#   '264': 'Oye24',
#   '265': 'Cafe Terazza',
#   '266': 'Cafe Palette',
#   '267': 'The Creative Kitchen - Radisson Blu Hotel',
#   '268': 'Waffle House',
#   '269': 'JAL - A Jungle Restaurant',
#   '270': '10 Downing Street',
#   '271': 'Mangosteen Cafe',
#   '272': 'The Yellow Chilli',
#   '273': 'Vidorra',
#   '274': 'Mama Loca',
#   '275': 'Nafees Restaurant',
#   '276': "Cakesmith's Alley",
#   '277': 'Freito',
#   '278': 'Cafe Yolo',
#   '279': 'Hobnob Gourmet Cafébar',
#   '280': 'Al Arabian Express',
#   '281': 'Sadhana Restaurant',
#   '282': 'Barbeque Ville',
#   '283': 'Spice Route',
#   '284': 'The Cafe Katta',
#   '285': 'Barbeque Nation',
#   '286': 'Soma at Sula',
#   '287': 'Little Italy',
#   '288': 'Curry Leaves',
#   '289': '12212',
#   '290': 'RiverDine Restaurant & Bar',
#   '291': 'Veg Aroma',
#   '292': 'Chai Tapri',
#   '293': 'Divtya Budhlya Wada Restaurant',
#   '294': 'Enter The Dragon',
#   '295': 'White X Sky Lounge',
#   '296': 'Eastern Spice',
#   '297': 'House Of Flavours',
#   '298': 'The Bake Studio',
#   '299': 'Hotel Radhakrishna',
#   '300': 'Barbeque Nation',
#   '301': 'Bistro 226',
#   '302': 'Aman Chicken',
#   '303': 'Nik Bakers',
#   '304': 'The Yellow Chilli',
#   '305': 'Bistro Flamme Bois',
#   '306': 'Hot Breads',
#   '307': 'Pirates Of Grill',
#   '308': 'Mocha',
#   '309': 'Hawai Adda',
#   '310': 'Kitchen At 95 - Hyatt Regency',
# ...
#   '199': 'Very Good',
#   '200': 'Very Good',
#   '201': 'Good',
#   '202': 'Very Good',
#   '203': 'Excellent',
#   '204': 'Very Good',
#   '205': 'Very Good',
#   '206': 'Very Good',
#   '207': 'Excellent',
#   '208': 'Very Good',
#   '209': 'Very Good',
#   '210': 'Good',
#   '211': 'Very Good',
#   '212': 'Very Good',
#   '213': 'Good',
#   '214': 'Very Good',
#   '215': 'Good',
#   '216': 'Very Good',
#   '217': 'Excellent',
#   '218': 'Good',
#   '219': 'Very Good',
#   '220': 'Very Good',
#   '221': 'Very Good',
#   '222': 'Very Good',
#   '223': 'Good',
#   '224': 'Very Good',
#   '225': 'Average',
#   '226': 'Excellent',
#   '227': 'Very Good',
#   '228': 'Good',
#   '229': 'Very Good',
#   '230': 'Very Good',
#   '231': 'Very Good',
#   '232': 'Very Good',
#   '233': 'Very Good',
#   '234': 'Very Good',
#   '235': 'Excellent',
#   '236': 'Very Good',
#   '237': 'Very Good',
#   '238': 'Average',
#   '239': 'Very Good',
#   '240': 'Very Good',
#   '241': 'Very Good',
#   '242': 'Good',
#   '243': 'Very Good',
#   '244': 'Very Good',
#   '245': 'Very Good',
#   '246': 'Excellent',
#   '247': 'Good',
#   '248': 'Excellent',
#   '249': 'Excellent',
#   '250': 'Excellent',
#   '251': 'Very Good',
#   '252': 'Excellent',
#   '253': 'Good',
#   '254': 'Excellent',
#   '255': 'Good',
#   '256': 'Very Good',
#   '257': 'Very Good',
#   '258': 'Very Good',
#   '259': 'Good',
#   '260': 'Very Good',
#   '261': 'Good',
#   '262': 'Good',
#   '263': 'Very Good',
#   '264': 'Very Good',
#   '265': 'Good',
#   '266': 'Good',
#   '267': 'Good',
#   '268': 'Very Good',
#   '269': 'Very Good',
#   '270': 'Very Good',
#   '271': 'Good',
#   '272': 'Very Good',
#   '273': 'Very Good',
#   '274': 'Very Good',
#   '275': 'Very Good',
#   '276': 'Very Good',
#   '277': 'Average',
#   '278': 'Good',
#   '279': 'Very Good',
#   '280': 'Good',
#   '281': 'Good',
#   '282': 'Good',
#   '283': 'Good',
#   '284': 'Average',
#   '285': 'Good',
#   '286': 'Average',
#   '287': 'Average',
#   '288': 'Average',
#   '289': 'Good',
#   '290': 'Good',
#   '291': 'Good',
#   '292': 'Average',
#   '293': 'Good',
#   '294': 'Average',
#   '295': 'Average',
#   '296': 'Good',
#   '297': 'Average',
#   '298': 'Good',
#   '299': 'Good',
#   '300': 'Good',
#   '301': 'Very Good',
#   '302': 'Excellent',
#   '303': 'Very Good',
#   '304': 'Very Good',
#   '305': 'Very Good',
#   '306': 'Very Good',
#   '307': 'Good',
#   '308': 'Good',
#   '309': 'Good',
#   '310': 'Very Good',
#   '311': 'Good',
#   '312': 'Very Good',
#   '313': 'Very Good',
#   '314': 'Good',
#   '315': 'Good',
#   '316': 'Good',
#   '317': 'Good',
#   '318': 'Good',
#   '319': 'Good',
#   '320': 'Excellent',
#   '321': 'Very Good',
#   '322': 'Very Good',
#   '323': 'Very Good',
#   '324': 'Excellent',
#   '325': 'Very Good',
#   '326': 'Good',
#   '327': 'Very Good',
#   '328': 'Very Good',
#   '329': 'Good',
#   '330': 'Excellent',
#   '331': 'Very Good',
#   '332': 'Good',
#   '333': 'Very Good',
#   '334': 'Very Good',
#   '335': 'Very Good',
#   '336': 'Very Good',
#   '337': 'Very Good',
#   '338': 'Very Good',
#   '339': 'Very Good',
#   '340': 'Average',
#   '341': 'Good',
#   '342': 'Good',
#   '343': 'Good',
#   '344': 'Good',
#   '345': 'Very Good',
#   '346': 'Good',
#   '347': 'Good',
#   '348': 'Good',
#   '349': 'Very Good',
#   '350': 'Good',
#   '351': 'Average',
#   '352': 'Good',
#   '353': 'Good',
#   '354': 'Average',
#   '355': 'Average',
#   '356': 'Good',
#   '357': 'Average',
#   '358': 'Good',
#   '359': 'Very Good',
#   '360': 'Average',
#   '361': 'Good',
#   '362': 'Very Good',
#   '363': 'Good',
#   '364': 'Average',
#   '365': 'Good',
#   '366': 'Good',
#   '367': 'Good',
#   '368': 'Good',
#   '369': 'Very Good',
#   '370': 'Very Good',
#   '371': 'Good',
#   '372': 'Very Good',
#   '373': 'Very Good',
#   '374': 'Very Good',
#   '375': 'Good',
#   '376': 'Good',
#   '377': 'Very Good',
#   '378': 'Average',
#   '379': 'Good',
#   '380': 'Average',
#   '381': 'Good',
#   '382': 'Average',
#   '383': 'Good',
#   '384': 'Good',
#   '385': 'Average',
#   '386': 'Average',
#   '387': 'Good',
#   '388': 'Average',
#   '389': 'Average',
#   '390': 'Average',
#   '391': 'Good',
#   '392': 'Average',
#   '393': 'Average',
#   '394': 'Average',
#   '395': 'Average',
#   '396': 'Average',
#   '397': 'Average',
#   '398': 'Average',
#   '399': 'Average',
#   '400': 'Good',
#   '401': 'Good',
#   '402': 'Average',
#   '403': 'Good',
#   '404': 'Good',
#   '405': 'Average',
#   '406': 'Average',
#   '407': 'Average',
#   '408': 'Average',
#   '409': 'Average',
#   '410': 'Average',
#   '411': 'Average',
#   '412': 'Average',
#   '413': 'Average',
#   '414': 'Average',
#   '415': 'Average',
#   '416': 'Average',
#   '417': 'Average',
#   '418': 'Average',
#   '419': 'Average',
#   '420': 'Very Good',
#   '421': 'Very Good',
#   '422': 'Good',
#   '423': 'Good',
#   '424': 'Good',
#   '425': 'Very Good',
#   '426': 'Very Good',
#   '427': 'Excellent',
#   '428': 'Very Good',
#   '429': 'Average',
#   '430': 'Good',
#   '431': 'Good',
#   '432': 'Good',
#   '433': 'Average',
#   '434': 'Very Good',
#   '435': 'Very Good',
#   '436': 'Very Good',
#   '437': 'Very Good',
#   '438': 'Good',
#   '439': 'Good',
#   '440': 'Good',
#   '441': 'Good',
#   '442': 'Very Good',
#   '443': 'Average',
#   '444': 'Good',
#   '445': 'Average',
#   '446': 'Good',
#   '447': 'Average',
#   '448': 'Good',
#   '449': 'Average',
#   '450': 'Average',
#   '451': 'Good',
#   '452': 'Good',
#   '453': 'Good',
#   '454': 'Average',
#   '455': 'Average',
#   '456': 'Average',
#   '457': 'Average',
#   '458': 'Average',
#   '459': 'Average',
#   '460': 'Very Good',
#   '461': 'Very Good',
#   '462': 'Excellent',
#   '463': 'Very Good',
#   '464': 'Good',
#   '465': 'Good',
#   '466': 'Good',
#   '467': 'Excellent',
#   '468': 'Very Good',
#   '469': 'Very Good',
#   '470': 'Good',
#   '471': 'Good',
#   '472': 'Good',
#   '473': 'Good',
#   '474': 'Good',
#   '475': 'Very Good',
#   '476': 'Very Good',
#   '477': 'Good',
#   '478': 'Good',
#   '479': 'Very Good',
#   '480': 'Good',
#   '481': 'Excellent',
#   '482': 'Very Good',
#   '483': 'Good',
#   '484': 'Good',
#   '485': 'Very Good',
#   '486': 'Good',
#   '487': 'Good',
#   '488': 'Good',
#   '489': 'Very Good',
#   '490': 'Very Good',
#   '491': 'Good',
#   '492': 'Good',
#   '493': 'Good',
#   '494': 'Very Good',
#   '495': 'Good',
#   '496': 'Very Good',
#   '497': 'Very Good',
#   '498': 'Very Good',
#   '499': 'Very Good',
#   '500': 'Very Good',
#   '501': 'Good',
#   '502': 'Very Good',
#   '503': 'Excellent',
#   '504': 'Good',
#   '505': 'Excellent',
#   '506': 'Very Good',
#   '507': 'Very Good',
#   '508': 'Very Good',
#   '509': 'Very Good',
#   '510': 'Very Good',
#   '511': 'Good',
#   '512': 'Very Good',
#   '513': 'Good',
#   '514': 'Very Good',
#   '515': 'Very Good',
#   '516': 'Very Good',
#   '517': 'Excellent',
#   '518': 'Good',
#   '519': 'Good',
#   '520': 'Very Good',
#   '521': 'Good',
#   '522': 'Good',
#   '523': 'Good',
#   '524': 'Good',
#   '525': 'Good',
#   '526': 'Good',
#   '527': 'Good',
#   '528': 'Good',
#   '529': 'Good',
#   '530': 'Very Good',
#   '531': 'Good',
#   '532': 'Good',
#   '533': 'Good',
#   '534': 'Good',
#   '535': 'Good',
#   '536': 'Good',
#   '537': 'Good',
#   '538': 'Good',
#   '539': 'Good',
#   '540': 'Very Good',
#   '541': 'Very Good',
#   '542': 'Good',
#   '543': 'Very Good',
#   '544': 'Excellent',
#   '545': 'Very Good',
#   '546': 'Very Good',
#   '547': 'Good',
#   '548': 'Good',
#   '549': 'Good',
#   '550': 'Good',
#   '551': 'Very Good',
#   '552': 'Good',
#   '553': 'Excellent',
#   '554': 'Very Good',
#   '555': 'Good',
#   '556': 'Very Good',
#   '557': 'Very Good',
#   '558': 'Good',
#   '559': 'Good',
#   '560': 'Excellent',
#   '561': 'Very Good',
#   '562': 'Excellent',
#   '563': 'Average',
#   '564': 'Very Good',
#   '565': 'Very Good',
#   '566': 'Very Good',
#   '567': 'Poor',
#   '568': 'Very Good',
#   '569': 'Good',
#   '570': 'Good',
#   '571': 'Good',
#   '572': 'Very Good',
#   '573': 'Very Good',
#   '574': 'Good',
#   '575': 'Very Good',
#   '576': 'Good',
#   '577': 'Very Good',
#   '578': 'Good',
#   '579': 'Very Good',
#   '580': 'Good',
#   '581': 'Excellent',
#   '582': 'Very Good',
#   '583': 'Very Good',
#   '584': 'Very Good',
#   '585': 'Good',
#   '586': 'Good',
#   '587': 'Good',
#   '588': 'Very Good',
#   '589': 'Very Good',
#   '590': 'Very Good',
#   '591': 'Good',
#   '592': 'Average',
#   '593': 'Very Good',
#   '594': 'Good',
#   '595': 'Very Good',
#   '596': 'Good',
#   '597': 'Very Good',
#   '598': 'Good',
#   '599': 'Good',
#   '600': 'Very Good',
#   '601': 'Very Good',
#   '602': 'Very Good',
#   '603': 'Good',
#   '604': 'Very Good',
#   '605': 'Excellent',
#   '606': 'Very Good',
#   '607': 'Good',
#   '608': 'Good',
#   '609': 'Very Good',
#   '610': 'Good',
#   '611': 'Very Good',
#   '612': 'Good',
#   '613': 'Good',
#   '614': 'Very Good',
#   '615': 'Very Good',
#   '616': 'Good',
#   '617': 'Good',
#   '618': 'Very Good',
#   '619': 'Good',
#   '620': 'Good',
#   '621': 'Good',
#   '622': 'Good',
#   '623': 'Very Good',
#   '624': 'Very Good',
#   '625': 'Good',
#   '626': 'Good',
#   '627': 'Good',
#   '628': 'Average',
#   '629': 'Very Good',
#   '630': 'Good',
#   '631': 'Good',
#   '632': 'Good',
#   '633': 'Good',
#   '634': 'Good',
#   '635': 'Average',
#   '636': 'Good',
#   '637': 'Good',
#   '638': 'Good',
#   '639': 'Good',
#   '640': 'Very Good',
#   '641': 'Good',
#   '642': 'Good',
#   '643': 'Very Good',
#   '644': 'Average',
#   '645': 'Good',
#   '646': 'Good',
#   '647': 'Good',
#   '648': 'Good',
#   '649': 'Good',
#   '650': 'Good',
#   '651': 'Good',
#   '652': 'Good',
#   '653': 'Good',
#   '654': 'Very Good',
#   '655': 'Average',
#   '656': 'Good',
#   '657': 'Good',
#   '658': 'Good',
#   '659': 'Good',
#   '660': 'Good',
#   '661': 'Very Good',
#   '662': 'Average',
#   '663': 'Very Good',
#   '664': 'Good',
#   '665': 'Very Good',
#   '666': 'Very Good',
#   '667': 'Very Good',
#   '668': 'Good',
#   '669': 'Good',
#   '670': 'Good',
#   '671': 'Good',
#   '672': 'Very Good',
#   '673': 'Good',
#   '674': 'Very Good',
#   '675': 'Very Good',
#   '676': 'Very Good',
#   '677': 'Very Good',
#   '678': 'Good',
#   '679': 'Good',
#   '680': 'Good',
#   '681': 'Good',
#   '682': 'Good',
#   '683': 'Good',
#   '684': 'Good',
#   '685': 'Good',
#   '686': 'Very Good',
#   '687': 'Average',
#   '688': 'Average',
#   '689': 'Good',
#   '690': 'Good',
#   '691': 'Good',
#   '692': 'Average',
#   '693': 'Average',
#   '694': 'Good',
#   '695': 'Average',
#   '696': 'Average',
#   '697': 'Average',
#   '698': 'Good',
#   '699': 'Average',
#   '700': 'Good',
#   '701': 'Good',
#   '702': 'Good',
#   '703': 'Good',
#   '704': 'Average',
#   '705': 'Good',
#   '706': 'Good',
#   '707': 'Good',
#   '708': 'Good',
#   '709': 'Average',
#   '710': 'Average',
#   '711': 'Good',
#   '712': 'Average',
#   '713': 'Average',
#   '714': 'Average',
#   '715': 'Good',
#   '716': 'Average',
#   '717': 'Good',
#   '718': 'Average',
#   '719': 'Average',
#   '720': 'Very Good',
#   '721': 'Excellent',
#   '722': 'Excellent',
#   '723': 'Excellent',
#   '724': 'Very Good',
#   '725': 'Very Good',
#   '726': 'Good',
#   '727': 'Excellent',
#   '728': 'Excellent',
#   '729': 'Excellent',
#   '730': 'Average',
#   '731': 'Excellent',
#   '732': 'Very Good',
#   '733': 'Excellent',
#   '734': 'Very Good',
#   '735': 'Very Good',
#   '736': 'Very Good',
#   '737': 'Good',
#   '738': 'Excellent',
#   '739': 'Very Good',
#   '740': 'Good',
#   '741': 'Average',
#   '742': 'Average',
#   '743': 'Good',
#   '744': 'Good',
#   '745': 'Average',
#   '746': 'Average',
#   '747': 'Average',
#   '748': 'Average',
#   '749': 'Good',
#   '750': 'Very Good',
#   '751': 'Average',
#   '752': 'Very Good',
#   '753': 'Good',
#   '754': 'Average',
#   '755': 'Very Good',
#   '756': 'Good',
#   '757': 'Average',
#   '758': 'Good',
#   '759': 'Good',
#   '760': 'Excellent',
#   '761': 'Very Good',
#   '762': 'Very Good',
#   '763': 'Very Good',
#   '764': 'Very Good',
#   '765': 'Good',
#   '766': 'Very Good',
#   '767': 'Poor',
#   '768': 'Very Good',
#   '769': 'Very Good',
#   '770': 'Excellent',
#   '771': 'Very Good',
#   '772': 'Very Good',
#   '773': 'Good',
#   '774': 'Very Good',
#   '775': 'Good',
#   '776': 'Good',
#   '777': 'Very Good',
#   '778': 'Good',
#   '779': 'Good',
#   '780': 'Excellent',
#   '781': 'Excellent',
#   '782': 'Excellent',
#   '783': 'Excellent',
#   '784': 'Excellent',
#   '785': 'Very Good',
#   '786': 'Very Good',
#   '787': 'Excellent',
#   '788': 'Very Good',
#   '789': 'Very Good',
#   '790': 'Very Good',
#   '791': 'Very Good',
#   '792': 'Very Good',
#   '793': 'Very Good',
#   '794': 'Very Good',
#   '795': 'Good',
#   '796': 'Very Good',
#   '797': 'Excellent',
#   '798': 'Very Good',
#   '799': 'Very Good',
#   '800': 'Very Good',
#   '801': 'Very Good',
#   '802': 'Very Good',
#   '803': 'Very Good',
#   '804': 'Very Good',
#   '805': 'Excellent',
#   '806': 'Very Good',
#   '807': 'Very Good',
#   '808': 'Good',
#   '809': 'Poor',
#   '810': 'Very Good',
#   '811': 'Good',
#   '812': 'Good',
#   '813': 'Good',
#   '814': 'Excellent',
#   '815': 'Very Good',
#   '816': 'Average',
#   '817': 'Very Good',
#   '818': 'Very Good',
#   '819': 'Average',
#   '820': 'Excellent',
#   '821': 'Excellent',
#   '822': 'Very Good',
#   '823': 'Excellent',
#   '824': 'Excellent',
#   '825': 'Very Good',
#   '826': 'Excellent',
#   '827': 'Good',
#   '828': 'Very Good',
#   '829': 'Good',
#   '830': 'Very Good',
#   '831': 'Very Good',
#   '832': 'Very Good',
#   '833': 'Good',
#   '834': 'Very Good',
#   '835': 'Very Good',
#   '836': 'Excellent',
#   '837': 'Very Good',
#   '838': 'Excellent',
#   '839': 'Very Good',
#   '840': 'Very Good',
#   '841': 'Excellent',
#   '842': 'Very Good',
#   '843': 'Excellent',
#   '844': 'Very Good',
#   '845': 'Very Good',
#   '846': 'Very Good',
#   '847': 'Excellent',
#   '848': 'Very Good',
#   '849': 'Very Good',
#   '850': 'Very Good',
#   '851': 'Good',
#   '852': 'Very Good',
#   '853': 'Very Good',
#   '854': 'Very Good',
#   '855': 'Average',
#   '856': 'Very Good',
#   '857': 'Very Good',
#   '858': 'Excellent',
#   '859': 'Excellent',
#   '860': 'Excellent',
#   '861': 'Excellent',
#   '862': 'Excellent',
#   '863': 'Excellent',
#   '864': 'Excellent',
#   '865': 'Excellent',
#   '866': 'Excellent',
#   '867': 'Excellent',
#   '868': 'Excellent',
#   '869': 'Excellent',
#   '870': 'Excellent',
#   '871': 'Very Good',
#   '872': 'Good',
#   '873': 'Excellent',
#   '874': 'Very Good',
#   '875': 'Very Good',
#   '876': 'Excellent',
#   '877': 'Excellent',
#   '878': 'Excellent',
#   '879': 'Very Good',
#   '880': 'Good',
#   '881': 'Average',
#   '882': 'Very Good',
#   '883': 'Excellent',
#   '884': 'Excellent',
#   '885': 'Average',
#   '886': 'Very Good',
#   '887': 'Excellent',
#   '888': 'Good',
#   '889': 'Very Good',
#   '890': 'Very Good',
#   '891': 'Good',
#   '892': 'Good',
#   '893': 'Good',
#   '894': 'Very Good',
#   '895': 'Very Good',
#   '896': 'Good',
#   '897': 'Excellent',
#   '898': 'Very Good',
#   '899': 'Good',
#   '900': 'Excellent',
#   '901': 'Excellent',
#   '902': 'Excellent',
#   '903': 'Excellent',
#   '904': 'Excellent',
#   '905': 'Very Good',
#   '906': 'Very Good',
#   '907': 'Very Good',
#   '908': 'Excellent',
#   '909': 'Excellent',
#   '910': 'Excellent',
#   '911': 'Excellent',
#   '912': 'Excellent',
#   '913': 'Very Good',
#   '914': 'Very Good',
#   '915': 'Very Good',
#   '916': 'Excellent',
#   '917': 'Very Good',
#   '918': 'Excellent',
#   '919': 'Very Good',
#   '920': 'Excellent',
#   '921': 'Very Good',
#   '922': 'Very Good',
#   '923': 'Good',
#   '924': 'Very Good',
#   '925': 'Very Good',
#   '926': 'Very Good',
#   '927': 'Very Good',
#   '928': 'Excellent',
#   '929': 'Good',
#   '930': 'Excellent',
#   '931': 'Good',
#   '932': 'Very Good',
#   '933': 'Good',
#   '934': 'Good',
#   '935': 'Good',
#   '936': 'Very Good',
#   '937': 'Good',
#   '938': 'Very Good',
#   '939': 'Very Good',
#   '940': 'Very Good',
#   '941': 'Excellent',
#   '942': 'Very Good',
#   '943': 'Very Good',
#   '944': 'Very Good',
#   '945': 'Very Good',
#   '946': 'Excellent',
#   '947': 'Excellent',
#   '948': 'Excellent',
#   '949': 'Very Good',
#   '950': 'Very Good',
#   '951': 'Very Good',
#   '952': 'Very Good',
#   '953': 'Very Good',
#   '954': 'Very Good',
#   '955': 'Very Good',
#   '956': 'Very Good',
#   '957': 'Excellent',
#   '958': 'Good',
#   '959': 'Very Good',
#   '960': 'Excellent',
#   '961': 'Very Good',
#   '962': 'Good',
#   '963': 'Good',
#   '964': 'Good',
#   '965': 'Very Good',
#   '966': 'Good',
#   '967': 'Average',
#   '968': 'Not rated',
#   '969': 'Very Good',
#   '970': 'Average',
#   '971': 'Average',
#   '972': 'Good',
#   '973': 'Average',
#   '974': 'Average',
#   '975': 'Good',
#   '976': 'Very Good',
#   '977': 'Good',
#   '978': 'Average',
#   '979': 'Good',
#   '980': 'Very Good',
#   '981': 'Excellent',
#   '982': 'Very Good',
#   '983': 'Very Good',
#   '984': 'Good',
#   '985': 'Not rated',
#   '986': 'Excellent',
#   '987': 'Not rated',
#   '988': 'Very Good',
#   '989': 'Very Good',
#   '990': 'Very Good',
#   '991': 'Good',
#   '992': 'Very Good',
#   '993': 'Average',
#   '994': 'Excellent',
#   '995': 'Very Good',
#   '996': 'Good',
#   '997': 'Excellent',
#   '998': 'Average',
#   '999': 'Not rated',
#   ...}}

# %%
df = pd.DataFrame.from_dict(json_data)

# %%
df
# Out:
#       has_online_delivery  price_range currency                        name  \
# 0                       1            3      Rs.            Hauz Khas Social
# 1                       0            3      Rs.  Qubitos - The Terrace Cafe
# 2                       1            2      Rs.             The Hudson Cafe
# 3                       0            3      Rs.           Summer House Cafe
# 4                       0            3      Rs.                 38 Barracks
# ...                   ...          ...      ...                         ...
# 1175                    0            3        £               The Boozy Cow
# 1176                    0            3        £                 La Favorita
# 1177                    0            3        £           Roseleaf Bar Cafe
# 1178                    0            3        £                   Civerinos
# 1179                    0            3        £             The Hanging Bat
#
#                                                cuisines  \
# 0            Continental, American, Asian, North Indian
# 1     Thai, European, Mexican, North Indian, Chinese...
# 2                   Cafe, Italian, Continental, Chinese
# 3                                  Italian, Continental
# 4                North Indian, Italian, Asian, American
# ...                                                 ...
# 1175                                      Burger, Grill
# 1176                                            Italian
# 1177                                     Scottish, Cafe
# 1178                                     Pizza, Italian
# 1179                                           American
#
#                                        location.address location.city  \
# 0                9-A & 12, Hauz Khas Village, New Delhi     New Delhi
# 1     C-7, Vishal Enclave, Opposite Metro Pillar 417...     New Delhi
# 2     2524, 1st Floor, Hudson Lane, Delhi University...     New Delhi
# 3     1st Floor, DDA Shopping Complex, Aurobindo Pla...     New Delhi
# 4        M-38, Outer Circle, Connaught Place, New Delhi     New Delhi
# ...                                                 ...           ...
# 1175   17 Frederick Street, New Town, Edinburgh EH2 2EY     Edinburgh
# 1176       325-331 Leith Walk, Leith, Edinburgh EH6 8SA     Edinburgh
# 1177     23-24 Sandport Place, Leith, Edinburgh EH6 6EW     Edinburgh
# 1178  5 Hunter Square, Royal Mile, Old Town, Edinbur...     Edinburgh
# 1179      133 Lothian Road, Old Town, Edinburgh EH3 9AD     Edinburgh
#
#      user_rating.rating_text
# 0                  Very Good
# 1                  Excellent
# 2                  Very Good
# 3                  Very Good
# 4                  Very Good
# ...                      ...
# 1175               Very Good
# 1176               Excellent
# 1177               Excellent
# 1178                    Good
# 1179                    Good
#
# [1180 rows x 8 columns]

# %% [markdown]
# ¡Listo! Ahora vamos a ver qué podemos hacer con este `DataFrame`.
