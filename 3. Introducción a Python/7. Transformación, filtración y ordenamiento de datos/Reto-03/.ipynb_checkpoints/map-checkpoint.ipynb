# %% [markdown]
# ## Reto 3: Map
#
# ### 1. Objetivos:
#     - Practicar el uso del método `map` para mapear un dato a otro dato que le corresponde.
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Booleanos a numéricos
#
# Vamos a trabajar sobre el dataset que guardaste en el Reto anterior. Esta vez tu Reto es muy sencillo:
#
# 1. La columna `is_potentially_hazardous_asteroid` tiene valores `booleanos`. Crea un diccionario de mapeo donde hagas un correspondencia de cada valor `booleano` con su equivalente numérico y transforma esa columna.
# 2. Usa una función para mapear la columna `relative_velocity.kilometers_per_hour` a una nueva columna llamada `relative_velocity.kilometers_per_minute`, que contenga la velocidad del objeto en kilómetros por minuto.
# 3. Guarda tu `DataFrame` resultante en la variable `df_reto_3`.
# 4. Guarda tu resultado en un archivo .csv.

# %%
import pandas as pd

df = pd.read_csv("C:/Users/LLerma/Google Drive/Analisis de Datos/M3 - Introduccion a Python/Files/My_files/Reto_2.csv")
df.dtypes
# Out:
# Unnamed: 0                                            int64
# Unnamed: 0.1                                          int64
# Unnamed: 0.1.1                                        int64
# id_name                                              object
# is_potentially_hazardous_asteroid                      bool
# estimated_diameter.meters.estimated_diameter_min    float64
# estimated_diameter.meters.estimated_diameter_max    float64
# close_approach_date                                  object
# epoch_date_close_approach                            object
# orbiting_body                                        object
# relative_velocity.kilometers_per_second             float64
# relative_velocity.kilometers_per_hour               float64
# orbit_class_description                              object
# id                                                    int64
# name                                                 object
# dtype: object

# %%
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                     id_name  \
# 0           0             0               0  2154652-154652 (2004 EP20)
# 1           1             1               1           3153509-(2003 HM)
# 2           2             2               2           3516633-(2010 HA)
# 3           3             3               3          3837644-(2019 AY3)
# 4           4             4               4           3843493-(2019 PY)
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                               True
# 2                              False
# 3                              False
# 4                              False
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        483.676488
# 1                                         96.506147
# 2                                         44.111820
# 3                                         46.190746
# 4                                         22.108281
#
#    estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 0                                       1081.533507          1995-01-07
# 1                                        215.794305          1995-01-07
# 2                                         98.637028          1995-01-07
# 3                                        103.285648          1995-01-07
# 4                                         49.435619          1995-01-07
#
#   epoch_date_close_approach orbiting_body  \
# 0       1995-01-07 08:33:00         Earth
# 1       1995-01-07 15:09:00         Earth
# 2       1995-01-07 02:47:00         Earth
# 3       1995-01-07 21:25:00         Earth
# 4       1995-01-07 02:45:00         Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                                16.142864
# 1                                12.351044
# 2                                 6.220435
# 3                                22.478615
# 4                                 4.998691
#
#    relative_velocity.kilometers_per_hour  \
# 0                           58114.308667
# 1                           44463.757734
# 2                                    NaN
# 3                           80923.015021
# 4                           17995.288355
#
#                              orbit_class_description       id  \
# 0  Near Earth asteroid orbits similar to that of ...  2154652
# 1  Near Earth asteroid orbits which cross the Ear...  3153509
# 2  Near Earth asteroid orbits similar to that of ...  3516633
# 3  Near Earth asteroid orbits similar to that of ...  3837644
# 4  Near Earth asteroid orbits similar to that of ...  3843493
#
#                  name
# 0  154652 (2004 EP20)
# 1           (2003 HM)
# 2           (2010 HA)
# 3          (2019 AY3)
# 4           (2019 PY)

# %%
# 1

dicc = {
    True : 1 ,
    False: 0
}

df['is_potentially_hazardous_asteroid'] = df['is_potentially_hazardous_asteroid'].map(dicc)
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                     id_name  \
# 0           0             0               0  2154652-154652 (2004 EP20)
# 1           1             1               1           3153509-(2003 HM)
# 2           2             2               2           3516633-(2010 HA)
# 3           3             3               3          3837644-(2019 AY3)
# 4           4             4               4           3843493-(2019 PY)
#
#    is_potentially_hazardous_asteroid  \
# 0                                  0
# 1                                  1
# 2                                  0
# 3                                  0
# 4                                  0
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        483.676488
# 1                                         96.506147
# 2                                         44.111820
# 3                                         46.190746
# 4                                         22.108281
#
#    estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 0                                       1081.533507          1995-01-07
# 1                                        215.794305          1995-01-07
# 2                                         98.637028          1995-01-07
# 3                                        103.285648          1995-01-07
# 4                                         49.435619          1995-01-07
#
#   epoch_date_close_approach orbiting_body  \
# 0       1995-01-07 08:33:00         Earth
# 1       1995-01-07 15:09:00         Earth
# 2       1995-01-07 02:47:00         Earth
# 3       1995-01-07 21:25:00         Earth
# 4       1995-01-07 02:45:00         Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                                16.142864
# 1                                12.351044
# 2                                 6.220435
# 3                                22.478615
# 4                                 4.998691
#
#    relative_velocity.kilometers_per_hour  \
# 0                           58114.308667
# 1                           44463.757734
# 2                                    NaN
# 3                           80923.015021
# 4                           17995.288355
#
#                              orbit_class_description       id  \
# 0  Near Earth asteroid orbits similar to that of ...  2154652
# 1  Near Earth asteroid orbits which cross the Ear...  3153509
# 2  Near Earth asteroid orbits similar to that of ...  3516633
# 3  Near Earth asteroid orbits similar to that of ...  3837644
# 4  Near Earth asteroid orbits similar to that of ...  3843493
#
#                  name
# 0  154652 (2004 EP20)
# 1           (2003 HM)
# 2           (2010 HA)
# 3          (2019 AY3)
# 4           (2019 PY)

# %%
# 2

def h_to_min(value):
    
    return value/60

df['relative_velocity.kilometers_per_minute'] = df['relative_velocity.kilometers_per_hour'].map(h_to_min)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                     id_name  \
# 0           0             0               0  2154652-154652 (2004 EP20)
# 1           1             1               1           3153509-(2003 HM)
# 2           2             2               2           3516633-(2010 HA)
# 3           3             3               3          3837644-(2019 AY3)
# 4           4             4               4           3843493-(2019 PY)
#
#    is_potentially_hazardous_asteroid  \
# 0                                  0
# 1                                  1
# 2                                  0
# 3                                  0
# 4                                  0
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        483.676488
# 1                                         96.506147
# 2                                         44.111820
# 3                                         46.190746
# 4                                         22.108281
#
#    estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 0                                       1081.533507          1995-01-07
# 1                                        215.794305          1995-01-07
# 2                                         98.637028          1995-01-07
# 3                                        103.285648          1995-01-07
# 4                                         49.435619          1995-01-07
#
#   epoch_date_close_approach orbiting_body  \
# 0       1995-01-07 08:33:00         Earth
# 1       1995-01-07 15:09:00         Earth
# 2       1995-01-07 02:47:00         Earth
# 3       1995-01-07 21:25:00         Earth
# 4       1995-01-07 02:45:00         Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                                16.142864
# 1                                12.351044
# 2                                 6.220435
# 3                                22.478615
# 4                                 4.998691
#
#    relative_velocity.kilometers_per_hour  \
# 0                           58114.308667
# 1                           44463.757734
# 2                                    NaN
# 3                           80923.015021
# 4                           17995.288355
#
#                              orbit_class_description       id  \
# 0  Near Earth asteroid orbits similar to that of ...  2154652
# 1  Near Earth asteroid orbits which cross the Ear...  3153509
# 2  Near Earth asteroid orbits similar to that of ...  3516633
# 3  Near Earth asteroid orbits similar to that of ...  3837644
# 4  Near Earth asteroid orbits similar to that of ...  3843493
#
#                  name  relative_velocity.kilometers_per_minute
# 0  154652 (2004 EP20)                               968.571811
# 1           (2003 HM)                               741.062629
# 2           (2010 HA)                                      NaN
# 3          (2019 AY3)                              1348.716917
# 4           (2019 PY)                               299.921473

# %%
df_reto_3 = df

# %% [markdown]
# Pídele a tu experta la función de verificación `revisar_resultados` (encontrada en el archivo `helpers.py` de la carpeta donde se encuentra este Reto), pégala debajo y corre la celda para verificar tu resultado:

# %%
def revisar_resultados(df_reto_3):
    
    import pandas as np
    import pandas.api.types as pdtypes
    
    assert pdtypes.is_int64_dtype(df_reto_3['is_potentially_hazardous_asteroid']), 'La columna "is_potentially_hazardous_asteroid" no ha sido transformada a tipo numerico'
    assert len(df_reto_3['is_potentially_hazardous_asteroid'].unique()) == 2, 'Hubo un error con la correspondencia de valores booleanos a numéricos. Hay más de dos valores posibles en la columna resultante'
    assert df_reto_3['relative_velocity.kilometers_per_minute'].equals(df_reto_3['relative_velocity.kilometers_per_hour'] / 60), 'La conversión de kilometros por hora a kilómetros por minuto no fue realizada correctamente'
    
    print(f'Todos los procesos fueron realizados exitosamente!')

revisar_resultados(df_reto_3)
# Out:
# Todos los procesos fueron realizados exitosamente!

# %%
df.to_csv("C:/Users/LLerma/Google Drive/Analisis de Datos/M3 - Introduccion a Python/Files/My_files/Reto_3.csv")

# %% [markdown]
# <details><summary>Solución</summary>
#
# ```python
# df = pd.read_csv('../../Datasets/near_earth_objects-jan_feb_1995-dirty.csv', index_col=0)
# mapa = {
#     True: 1,
#     False: 0
# }
# df['is_potentially_hazardous_asteroid'] = df['is_potentially_hazardous_asteroid'].map(mapa)
# def kilometers_per_hour_to_per_minute(value):
#     return value / 60
#
# df['relative_velocity.kilometers_per_hour'] = pd.to_numeric(df['relative_velocity.kilometers_per_hour'], errors='coerce')
# df['relative_velocity.kilometers_per_minute'] = df['relative_velocity.kilometers_per_hour'].map(kilometers_per_hour_to_per_minute)
# ```
#
# </details>
