# %% [markdown]
# ## Reto 5: Filtros
#
# ### 1. Objetivos:
#     - Practicar el uso de filtros para la obtención de subconjuntos de datos
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Filtrando por fechas, booleanos y valores numéricos
#
# Vamos a trabajar con el mismo dataset que guardaste del Reto anterior. Este Reto consiste en los siguiente:
#
# Usando filtros, crea 3 subconjuntos de datos:
#
# 1. Un subconjunto llamado `df_hazardous` que contenga sólo los records que correspondan a los objetos donde `is_potentially_hazardous_asteroid` sea `True` (o `1`).
# 2. Un subconjunto llamado `df_greater_than_1000` que contenga sólo los records donde el `estimated_diameter.meters.estimated_diameter_max` sea mayor a 1000 metros.
# 3. Un subconjunto llamado `df_february` que contenga sólo los records que pertenezcan exactamente al mes de Febrero de 1995. Recuerda que los datos en la columna `epoch_date_close_approach` están en milisegundos.

# %%
import pandas as pd
import datetime

df = pd.read_csv('C:/Users/LLerma/Google Drive/Analisis de Datos/M3 - Introduccion a Python/Files/My_files/Reto_4.csv')
df.head(2)
# Out:
#    Unnamed: 0                     id_name  is_potentially_hazardous_asteroid  \
# 0           0  2154652-154652 (2004 EP20)                                  0
# 1           1           3153509-(2003 HM)                                  1
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        483.676488
# 1                                         96.506147
#
#    estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 0                                       1081.533507          07/01/1995
# 1                                        215.794305          07/01/1995
#
#   epoch_date_close_approach orbiting_body  \
# 0          07/01/1995 08:33         Earth
# 1          07/01/1995 15:09         Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                                16.142864
# 1                                12.351044
#
#    relative_velocity.kilometers_per_hour  \
# 0                            58114.30867
# 1                            44463.75773
#
#                              orbit_class_description       id  \
# 0  Near Earth asteroid orbits similar to that of ...  2154652
# 1  Near Earth asteroid orbits which cross the Ear...  3153509
#
#                  name  relative_velocity.kilometers_per_minute  \
# 0  154652 (2004 EP20)                               968.571811
# 1           (2003 HM)                               741.062629
#
#    proportion_of_max_diameter_to_earth
# 0                             0.000085
# 1                             0.000017

# %%
df_hazardous = df[df["is_potentially_hazardous_asteroid"] ==1]

# %%
df_bigger_than_1000 =  df[df["estimated_diameter.meters.estimated_diameter_max"] > 1000]

# %%
df["epoch_date_close_approach"] = pd.to_datetime(df["epoch_date_close_approach"])

# %%
df_february = df[(df["epoch_date_close_approach"] > "1995-01-31") & (df["epoch_date_close_approach"] < "1995-03-01") ]
df_february
# Out:
#      Unnamed: 0                      id_name  \
# 33           33          3553279-(2010 XB24)
# 34           34           3825428-(2018 MA5)
# 35           35           3639467-(2013 LC1)
# 36           36          3703059-(2014 YE15)
# 37           37            3943319-(2019 YS)
# ..          ...                          ...
# 328         328  2267136-267136 (2000 EF104)
# 329         329           3360486-(2006 WE4)
# 330         330           3656919-(2014 BG3)
# 331         331           3803762-(2018 GY4)
# 332         332           3989652-(2020 CH1)
#
#      is_potentially_hazardous_asteroid  \
# 33                                   1
# 34                                   0
# 35                                   0
# 36                                   0
# 37                                   0
# ..                                 ...
# 328                                  0
# 329                                  0
# 330                                  0
# 331                                  0
# 332                                  0
#
#      estimated_diameter.meters.estimated_diameter_min  \
# 33                                         116.025908
# 34                                          14.606796
# 35                                          44.111820
# 36                                           5.815070
# 37                                           1.332156
# ..                                                ...
# 328                                        441.118200
# 329                                        441.118200
# 330                                        160.160338
# 331                                        421.264611
# 332                                         21.525586
#
#      estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 33                                         259.441818          02/01/1995
# 34                                          32.661790          02/01/1995
# 35                                          98.637028          02/01/1995
# 36                                          13.002893          02/01/1995
# 37                                           2.978791          02/01/1995
# ..                                                ...                 ...
# 328                                        986.370281          21/02/1995
# 329                                        986.370281          21/02/1995
# 330                                        358.129403          21/02/1995
# 331                                        941.976306          21/02/1995
# 332                                         48.132673          21/02/1995
#
#     epoch_date_close_approach orbiting_body  \
# 33        1995-02-01 15:12:00         Earth
# 34        1995-02-01 03:28:00         Earth
# 35        1995-02-01 19:37:00         Earth
# 36        1995-02-01 13:00:00         Earth
# 37        1995-02-01 22:41:00         Earth
# ..                        ...           ...
# 328       1995-02-21 04:17:00         Earth
# 329       1995-02-21 15:44:00         Earth
# 330       1995-02-21 12:08:00         Earth
# 331       1995-02-21 12:54:00         Earth
# 332       1995-02-21 22:15:00         Earth
#
#      relative_velocity.kilometers_per_second  \
# 33                                 14.978259
# 34                                  6.402162
# 35                                 11.580236
# 36                                 15.112868
# 37                                  2.975535
# ..                                       ...
# 328                                16.180392
# 329                                15.106140
# 330                                20.343173
# 331                                29.732426
# 332                                 6.998083
#
#      relative_velocity.kilometers_per_hour  \
# 33                             53921.73159
# 34                             23047.78324
# 35                             41688.85075
# 36                             54406.32626
# 37                             10711.92622
# ..                                     ...
# 328                            58249.41019
# 329                            54382.10464
# 330                            73235.42352
# 331                           107036.73310
# 332                                    NaN
#
#                                orbit_class_description       id  \
# 33   Near Earth asteroid orbits similar to that of ...  3553279
# 34   Near Earth asteroid orbits similar to that of ...  3825428
# 35   An asteroid orbit contained entirely within th...  3639467
# 36   Near Earth asteroid orbits similar to that of ...  3703059
# 37   Near Earth asteroid orbits which cross the Ear...  3943319
# ..                                                 ...      ...
# 328  Near Earth asteroid orbits similar to that of ...  2267136
# 329  Near Earth asteroid orbits which cross the Ear...  3360486
# 330  An asteroid orbit contained entirely within th...  3656919
# 331  Near Earth asteroid orbits similar to that of ...  3803762
# 332  Near Earth asteroid orbits similar to that of ...  3989652
#
#                     name  relative_velocity.kilometers_per_minute  \
# 33           (2010 XB24)                               898.695526
# 34            (2018 MA5)                               384.129721
# 35            (2013 LC1)                               694.814179
# 36           (2014 YE15)                               906.772104
# 37             (2019 YS)                               178.532104
# ..                   ...                                      ...
# 328  267136 (2000 EF104)                               970.823503
# 329           (2006 WE4)                               906.368411
# 330           (2014 BG3)                              1220.590392
# 331           (2018 GY4)                              1783.945551
# 332           (2020 CH1)                                      NaN
#
#      proportion_of_max_diameter_to_earth
# 33                          2.036115e-05
# 34                          2.563317e-06
# 35                          7.741095e-06
# 36                          1.020475e-06
# 37                          2.337773e-07
# ..                                   ...
# 328                         7.741095e-05
# 329                         7.741095e-05
# 330                         2.810622e-05
# 331                         7.392688e-05
# 332                         3.777482e-06
#
# [110 rows x 15 columns]

# %% [markdown]
# Pídele a tu experta la función de verificación `checar_subconjuntos` (encontrada en el archivo `helpers.py` de la carpeta donde se encuentra este Reto), pégala debajo y corre la celda para verificar tu resultado:

# %%
def checar_subconjuntos(df_february, df_hazardous, df_bigger_than_1000):
    
    import pandas as pd

    assert (df_hazardous['is_potentially_hazardous_asteroid'] == 0).sum() == 0, 'Algunos records en `df_hazardous` pertenecen a objetos donde is_potentially_hazardous_asteroid es `False`'
    assert (df_hazardous['is_potentially_hazardous_asteroid'] == 1).sum() > 0, 'No hay ningun record en `df_hazardous` donde is_potentially_hazardous_asteroid sea `True`'
    
    assert (df_bigger_than_1000['estimated_diameter.meters.estimated_diameter_max'] <= 1000).sum() == 0, 'Algunos records en `df_bigger_than_1000` pertenecen a objetos con diámetro menor a 1000 metros'
    assert (df_bigger_than_1000['estimated_diameter.meters.estimated_diameter_max'] > 1000).sum() > 0, 'No hay ningún record en `df_bigger_than_1000` que pertenezca a objetos con diámetro mayor a 1000 metros'
    
    february = pd.to_datetime('1995-02-01', format='%Y-%m-%d').timestamp() * 1000
    march = pd.to_datetime('1995-03-01', format='%Y-%m-%d').timestamp() * 1000 
    
    assert (df_february['epoch_date_close_approach'] < february).sum() == 0, 'Algunos records de `df_february` pertenecen a meses anteriores a Febrero de 1995'
    assert (df_february['epoch_date_close_approach'] >= march).sum() == 0, 'Algunos records de `df_february` pertenecen a meses posteriores a Febrero de 1995'
    
    print('Todos tus subconjuntos son correctos. ¡Gran trabajo!')

checar_subconjuntos(df_february, df_hazardous, df_bigger_than_1000)
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\arrays\datetimelike.py in _cmp_method(self, other, op)
#     931         try:
# --> 932             other = self._validate_comparison_value(other)
#     933         except InvalidComparison:
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\arrays\datetimelike.py in _validate_comparison_value(self, other)
#     450         elif not is_list_like(other):
# --> 451             raise InvalidComparison(other)
#     452
#
# InvalidComparison: 791596800000.0
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a89e2b82e817> in <module>
#      17     print('Todos tus subconjuntos son correctos. ¡Gran trabajo!')
#      18
# ---> 19 checar_subconjuntos(df_february, df_hazardous, df_bigger_than_1000)
#
# <ipython-input-8-a89e2b82e817> in checar_subconjuntos(df_february, df_hazardous, df_bigger_than_1000)
#      12     march = pd.to_datetime('1995-03-01', format='%Y-%m-%d').timestamp() * 1000
#      13
# ---> 14     assert (df_february['epoch_date_close_approach'] < february).sum() == 0, 'Algunos records de `df_february` pertenecen a meses anteriores a Febrero de 1995'
#      15     assert (df_february['epoch_date_close_approach'] >= march).sum() == 0, 'Algunos records de `df_february` pertenecen a meses posteriores a Febrero de 1995'
#      16
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      35     @unpack_zerodim_and_defer("__lt__")
#      36     def __lt__(self, other):
# ---> 37         return self._cmp_method(other, operator.lt)
#      38
#      39     @unpack_zerodim_and_defer("__le__")
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     227     if should_extension_dispatch(lvalues, rvalues):
#     228         # Call the method on lvalues
# --> 229         res_values = op(lvalues, rvalues)
#     230
#     231     elif is_scalar(rvalues) and isna(rvalues):
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      35     @unpack_zerodim_and_defer("__lt__")
#      36     def __lt__(self, other):
# ---> 37         return self._cmp_method(other, operator.lt)
#      38
#      39     @unpack_zerodim_and_defer("__le__")
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\arrays\datetimelike.py in _cmp_method(self, other, op)
#     932             other = self._validate_comparison_value(other)
#     933         except InvalidComparison:
# --> 934             return invalid_comparison(self, other, op)
#     935
#     936         dtype = getattr(other, "dtype", None)
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\pandas\core\ops\invalid.py in invalid_comparison(left, right, op)
#      32     else:
#      33         typ = type(right).__name__
# ---> 34         raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      35     return res_values
#      36
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and float

# %% [markdown]
# <details><summary>Solución</summary>
#
# ```python
# df = pd.read_csv('../../Datasets/near_earth_objects-jan_feb_1995-raw.csv', index_col=0)
# df_hazardous = df[df['is_potentially_hazardous_asteroid'] == 1]
# df_bigger_than_1000 = df[df['estimated_diameter.meters.estimated_diameter_max'] > 1000]
# february = pd.to_datetime('1995-02-01', format='%Y-%m-%d').timestamp() * 1000
# march = pd.to_datetime('1995-03-01', format='%Y-%m-%d').timestamp() * 1000
# greater_or_equal_than_february = df['epoch_date_close_approach'] >= february
# less_than_march = df['epoch_date_close_approach'] < march
# df_february = df[greater_or_equal_than_february & less_than_march]
# ```
#
# </details>
