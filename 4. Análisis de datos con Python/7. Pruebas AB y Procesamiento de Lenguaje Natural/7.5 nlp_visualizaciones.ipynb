# %% [markdown]
# ## Ejemplo 5: NLP y Visualizaciones
#
# ### 1. Objetivos:
#     - Aprender qué visualizaciones podemos realizar de nuestros procesamientos de lenguaje natural
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Como ya bien sabes, las visualizaciones son una parte esencial de nuestros análisis. Vamos a aprender cómo realizar algunas visualizaciones de los análisis estadísticos que ya hemos realizado. Esto nos ayudará a presentar nuestros hallazgos de manera más efectiva.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_json('../Datasets/new_york_times_bestsellers-clean.json')

df.head()
# Out:
#                                   amazon_product_url  \
# 0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4  http://www.amazon.com/Sundays-at-Tiffanys-Jame...
#
#                                      author  \
# 0                           Stephenie Meyer
# 1                              Emily Giffin
# 2                         Patricia Cornwell
# 3                           Chuck Palahniuk
# 4  James Patterson and Gabrielle Charbonnet
#
#                                          description      publisher  \
# 0  Aliens have taken control of the minds and bod...  Little, Brown
# 1  A woman's happy marriage is shaken when she en...   St. Martin's
# 2  A Massachusetts state investigator and his tea...         Putnam
# 3  An aging porn queens aims to cap her career by...      Doubleday
# 4                   A woman finds an unexpected love  Little, Brown
#
#                       title                       oid  \
# 0                  THE HOST  5b4aa4ead3089013507db18c
# 1  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                 THE FRONT  5b4aa4ead3089013507db18e
# 3                     SNUFF  5b4aa4ead3089013507db18f
# 4      SUNDAYS AT TIFFANY’S  5b4aa4ead3089013507db190
#
#    bestsellers_date.numberLong  published_date.numberLong  rank.numberInt  \
# 0                1211587200000              1212883200000               2
# 1                1211587200000              1212883200000               3
# 2                1211587200000              1212883200000               4
# 3                1211587200000              1212883200000               5
# 4                1211587200000              1212883200000               6
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95
# 3                         0                        1               24.95
# 4                         3                        4               24.99

# %%
df['rank.numberInt'].unique()
# Out:
# array([ 2,  3,  4,  5,  6,  7,  8,  9, 10, 12, 13, 14,  1, 11, 15, 16],
#       dtype=int64)

# %%
grouped_by_title = df.groupby('title')['description'].max()
grouped_by_title = grouped_by_title.str.lower()
grouped_by_title = grouped_by_title.str.strip()
grouped_by_title = grouped_by_title.str.replace('[^\w\s]', '')
grouped_by_title = grouped_by_title.str.replace('\d', '')
grouped_by_title = grouped_by_title.str.replace('\\n', '')
grouped_by_title = grouped_by_title.dropna()

tokenized = grouped_by_title.apply(nltk.word_tokenize)
all_words = tokenized.sum()

english_stop_words = stopwords.words('english')
all_words_except_stop_words = [word for word in all_words if word not in english_stop_words]

freq_dist = nltk.FreqDist(all_words_except_stop_words)
# Out:
# <ipython-input-4-e2be123c3b64>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   grouped_by_title = grouped_by_title.str.replace('[^\w\s]', '')
# <ipython-input-4-e2be123c3b64>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   grouped_by_title = grouped_by_title.str.replace('\d', '')
# <ipython-input-4-e2be123c3b64>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   grouped_by_title = grouped_by_title.str.replace('\\n', '')

# %%
# Podemos visualizar la frecuencia de las palabras más comunes

most_common_20 = np.array(list(map(lambda x: list(x), freq_dist.most_common(20))))

fig = plt.figure()
ax = fig.add_subplot()

sns.barplot(most_common_20[:, 0], most_common_20[:, 1], ax=ax, palette='RdYlBu');
ax.set_title('Frecuencia de las 20 palabras más comunes', pad=10)
ax.set_ylabel('Count')
ax.tick_params(axis='x', rotation=80)
# Out:
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e22180ba6ea0> in <module>
#       6 ax = fig.add_subplot()
#       7
# ----> 8 sns.barplot(most_common_20[:, 0], most_common_20[:, 1], ax=ax, palette='RdYlBu');
#       9 ax.set_title('Frecuencia de las 20 palabras más comunes', pad=10)
#      10 ax.set_ylabel('Count')
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
#    3181                           orient, color, palette, saturation,
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1343     elif require_numeric and "numeric" not in (x_type, y_type):
#    1344         err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1345         raise TypeError(err)
#    1346
#    1347     else:
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.

# %%
most_common_50 = np.array(list(map(lambda x: list(x), freq_dist.most_common(50))))

fig = plt.figure(figsize=(6, 10))
ax = fig.add_subplot()

sns.barplot(most_common_50[:, 1], most_common_50[:, 0], ax=ax, palette='RdYlBu', orient='h');
ax.set_title('Frecuencia de las 50 palabras más comunes', pad=10)
ax.set_xlabel('Count');

# %%
# También podemos visualizar la frecuencia de los bigramas más comunes

text = nltk.Text(all_words)
freq_dist_bigrams = nltk.FreqDist(list(nltk.bigrams(text)))

freq_dist_bigrams
# Out:
# FreqDist({('of', 'the'): 105, ('in', 'the'): 99, ('of', 'a'): 93, ('in', 'a'): 61, ('and', 'a'): 38, ('a', 'woman'): 34, ('book', 'of'): 33, ('for', 'the'): 32, ('to', 'the'): 31, ('and', 'the'): 30, ...})

# %%
most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_bigrams.most_common(20))))

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot()

sns.barplot(most_common_20[:, 0], most_common_20[:, 1], ax=ax, palette='RdYlBu');
ax.set_title('Frecuencia de las 20 bigramas más comunes', pad=10)
ax.set_ylabel('Count')
ax.tick_params(axis='x', rotation=80)
# Out:
# <ipython-input-7-0cf8d1d26028>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_bigrams.most_common(20))))
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Probemos sin palabras vacías

text = nltk.Text(all_words_except_stop_words)
freq_dist_bigrams = nltk.FreqDist(list(nltk.bigrams(text)))

freq_dist_bigrams
# Out:
# FreqDist({('new', 'york'): 26, ('serial', 'killer'): 18, ('stone', 'barrington'): 12, ('los', 'angeles'): 10, ('eve', 'dallas'): 10, ('writing', 'pseudonymously'): 10, ('lt', 'eve'): 9, ('nora', 'roberts'): 9, ('roberts', 'writing'): 9, ('fbi', 'agent'): 8, ...})

# %%
most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_bigrams.most_common(20))))

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot()

sns.barplot(most_common_20[:, 0], most_common_20[:, 1], ax=ax, palette='RdYlBu');
ax.set_title('Frecuencia de las 20 bigramas más comunes sin palabras vacías', pad=10)
ax.set_ylabel('Count')
ax.tick_params(axis='x', rotation=80)
# Out:
# <ipython-input-9-259e302b17cc>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_bigrams.most_common(20))))
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# No estamos restringidos solamente a bigramas

from nltk.util import ngrams

# %%
text = nltk.Text(all_words)
freq_dist_trigrams = nltk.FreqDist(list(ngrams(text, 3)))

most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_trigrams.most_common(20))))

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot()

sns.barplot(most_common_20[:, 0], most_common_20[:, 1], ax=ax, palette='RdYlBu');
ax.set_title('Frecuencia de las 20 trigramas más comunes con palabras vacías', pad=10)
ax.set_ylabel('Count')
ax.tick_params(axis='x', rotation=80)
# Out:
# <ipython-input-11-3bb652ef8e68>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_trigrams.most_common(20))))
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
text = nltk.Text(all_words_except_stop_words)
freq_dist_trigrams = nltk.FreqDist(list(ngrams(text, 3)))

most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_trigrams.most_common(20))))

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot()

sns.barplot(most_common_20[:, 0], most_common_20[:, 1], ax=ax, palette='RdYlBu');
ax.set_title('Frecuencia de las 20 trigramas más comunes sin palabras vacías', pad=10)
ax.set_ylabel('Count')
ax.tick_params(axis='x', rotation=80)
# Out:
# <ipython-input-12-a67cb18e6d4b>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   most_common_20 = np.array(list(map(lambda x: list(x), freq_dist_trigrams.most_common(20))))
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# También podemos generar histogramas para visualizar la frecuencia de longitudes de palabras y oraciones

word_lengths = [len(w) for w in all_words_except_stop_words]

# %%
sns.distplot(word_lengths, kde=False, norm_hist=False);
# Out:
# C:\Otro\Anaconda\envs\Class_test\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sentence_lengths = grouped_by_title.apply(lambda x: len(x))

# %%
sns.distplot(sentence_lengths, kde=False, norm_hist=False);

# %%
num_of_words = grouped_by_title.str.split(' ').str.len()

# %%
sns.distplot(num_of_words, kde=False, norm_hist=False);

# %% [markdown]
# Para terminar, vamos a hacer una nube de palabras utilizando la librería `wordcloud`.

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(max_font_size=100, background_color="white").generate(' '.join(all_words_except_stop_words))

plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
